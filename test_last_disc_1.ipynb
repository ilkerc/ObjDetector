# %%
# %matplotlib inline
import os
import time
import matplotlib
import lasagne
import theano
import theano.tensor as T
import pylab as P
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle
from DiscreteLayer import DiscreteLayer
#lasagne.random.set_rng(np.random.RandomState(1234))  # Set random state so we can investigate results
#np.random.seed(123)
# Out:
# Using gpu device 0: Tesla K40c (CNMeM is enabled with initial size: 33.0% of memory, cuDNN 5105)
# /home/ilker/anaconda2/envs/theano/lib/python2.7/site-packages/theano/sandbox/cuda/__init__.py:601: UserWarning: Your cuDNN version is more recent than the one Theano officially supports. If you see any problems, try updating Theano or downgrading cuDNN to version 5.
#   warnings.warn(warn)

# %%
# Constants
# theano.config.exception_verbosity = 'high'
conv = lasagne.layers.Conv2DLayer
pool = lasagne.layers.MaxPool2DLayer
NUM_EPOCHS = 1500
BATCH_SIZE = 256
LEARNING_RATE = 0.001
DIM = 60
NUM_CLASSES = 10
mnist_cluttered = "mnist_cluttered_60x60_6distortions.npz"
#DISC
DISC = True
MINS = (.3, -.3, -.8, -.3, .5, -0.7)
MAXS = (1.1, .1, 1.1, .4, 1.1, 1.5)
RANGES = (50, 50, 50, 50, 50, 50)
QUANT = np.array([0.008, 0.004, 0.019, 0.007, 0.006, 0.024], dtype='float32')
#Test Specs
TH_ACC = 0.98
NUM_TEST = 10
TEST_NAME = 'test1_disc_quantize'

# %%
def load_data():
    data = np.load(mnist_cluttered)
    X_train, y_train = data['x_train'], np.argmax(data['y_train'], axis=-1)
    X_valid, y_valid = data['x_valid'], np.argmax(data['y_valid'], axis=-1)
    X_test, y_test = data['x_test'], np.argmax(data['y_test'], axis=-1)

    # reshape for convolutions
    X_train = X_train.reshape((X_train.shape[0], 1, DIM, DIM))
    X_valid = X_valid.reshape((X_valid.shape[0], 1, DIM, DIM))
    X_test = X_test.reshape((X_test.shape[0], 1, DIM, DIM))
    
    print "Train samples:", X_train.shape
    print "Validation samples:", X_valid.shape
    print "Test samples:", X_test.shape

    return dict(
        X_train=lasagne.utils.floatX(X_train),
        y_train=y_train.astype('int32'),
        X_valid=lasagne.utils.floatX(X_valid),
        y_valid=y_valid.astype('int32'),
        X_test=lasagne.utils.floatX(X_test),
        y_test=y_test.astype('int32'),
        num_examples_train=X_train.shape[0],
        num_examples_valid=X_valid.shape[0],
        num_examples_test=X_test.shape[0],
        input_height=X_train.shape[2],
        input_width=X_train.shape[3],
        output_dim=10,)
data = load_data()
# Out:
# Train samples: (50000, 1, 60, 60)
# Validation samples: (10000, 1, 60, 60)
# Test samples: (10000, 1, 60, 60)

# %%
def build_model(input_width, input_height, output_dim, mins, maxs, ranges,
                batch_size=BATCH_SIZE, withdisc=True):
    ini = lasagne.init.HeUniform()
    l_in = lasagne.layers.InputLayer(shape=(None, 1, input_width, input_height),)
    #l_in = lasagne.layers.DropoutLayer(l_in, p=0.1)

    # Localization network
    b = np.zeros((2, 3), dtype=theano.config.floatX)
    b[0, 0] = 1
    b[1, 1] = 1
    b = b.flatten()
    loc_l1 = pool(l_in, pool_size=(2, 2))
    loc_l2 = conv(
        loc_l1, num_filters=20, filter_size=(5, 5), W=ini)
    loc_l3 = pool(loc_l2, pool_size=(2, 2))
    loc_l4 = conv(loc_l3, num_filters=20, filter_size=(5, 5), W=ini)
    loc_l5 = lasagne.layers.DenseLayer(
        loc_l4, num_units=50, W=lasagne.init.HeUniform('relu'))
    loc_out = lasagne.layers.DenseLayer(
        loc_l5, num_units=6, b=b, W=lasagne.init.Constant(0.0), 
        nonlinearity=lasagne.nonlinearities.identity, name='param_regressor')
    
    if withdisc:
        l_dis = DiscreteLayer(loc_out, mins, maxs, ranges, QUANT, name='disclayer')
        print("Using Discret. Layer")
    else:
        l_dis = loc_out
        print("No Disc. Layer")
    
    # Transformer network
    l_trans1 = lasagne.layers.TransformerLayer(l_in, l_dis, downsample_factor=3.0)
    print "Transformer network output shape: ", l_trans1.output_shape
    
    # Classification network
    class_l1 = conv(
        l_trans1,
        num_filters=32,
        filter_size=(3, 3),
        nonlinearity=lasagne.nonlinearities.rectify,
        W=ini,
    )
    class_l2 = pool(class_l1, pool_size=(2, 2))
    class_l3 = conv(
        class_l2,
        num_filters=32,
        filter_size=(3, 3),
        nonlinearity=lasagne.nonlinearities.rectify,
        W=ini,
    )
    class_l4 = pool(class_l3, pool_size=(2, 2))
    class_l5 = lasagne.layers.DenseLayer(
        class_l4,
        num_units=256,
        nonlinearity=lasagne.nonlinearities.rectify,
        W=ini,
    )

    l_out = lasagne.layers.DenseLayer(
        class_l5,
        num_units=output_dim,
        nonlinearity=lasagne.nonlinearities.softmax,
        W=ini,
    )

    return l_out, l_trans1

model, l_transform = build_model(DIM, DIM, NUM_CLASSES, MINS, MAXS, RANGES, withdisc=DISC)
model_params = lasagne.layers.get_all_params(model, trainable=True)
# Out:
# Using Discret. Layer
# Transformer network output shape:  (None, 1, 20, 20)

# %%
X = T.tensor4(dtype=theano.config.floatX)
y = T.ivector()

## Layer History
if DISC:
    l_disc = next(l for l in lasagne.layers.get_all_layers(model) if l.name is 'disclayer')
    l_paramreg = next(l for l in lasagne.layers.get_all_layers(model) if l.name is 'param_regressor')
    l_disc_output, l_paramreg_output = lasagne.layers.get_output([l_disc, l_paramreg], X, deterministic=False)
## Layer History

# training output
output_train = lasagne.layers.get_output(model, X, deterministic=False)

# evaluation output. Also includes output of transform for plotting
output_eval, transform_eval = lasagne.layers.get_output([model, l_transform], X, deterministic=True)

sh_lr = theano.shared(lasagne.utils.floatX(LEARNING_RATE))
cost = T.mean(T.nnet.categorical_crossentropy(output_train, y))
#updates = lasagne.updates.sgd(cost, model_params, LEARNING_RATE)
updates = lasagne.updates.adam(cost, model_params, learning_rate=sh_lr)

if DISC:
    train = theano.function([X, y], [cost, output_train, l_disc_output, l_paramreg_output], updates=updates)
else:
    train = theano.function([X, y], [cost, output_train], updates=updates)
eval = theano.function([X], [output_eval, transform_eval])

# %%
def train_epoch(X, y):
    # History Keeping
    param_output = []
    disc_output = []
    # History
    num_samples = X.shape[0]
    num_batches = int(np.ceil(num_samples / float(BATCH_SIZE)))
    costs = []
    correct = 0
    for i in range(num_batches):
        idx = range(i*BATCH_SIZE, np.minimum((i+1)*BATCH_SIZE, num_samples))
        X_batch = X[idx]
        y_batch = y[idx]
        if DISC:
            cost, output_train, l_disc_output, l_paramreg_output = train(X_batch, y_batch)
            param_output = np.append(param_output, l_paramreg_output)
            disc_output = np.append(disc_output, l_disc_output)
        else:
            cost, output_train = train(X_batch, y_batch)
        costs += [cost]
        preds = np.argmax(output_train, axis=-1)
        correct += np.sum(y_batch == preds)
        
    return np.mean(costs), correct / float(num_samples), param_output, disc_output


def eval_epoch(X, y):
    output_eval, transform_eval = eval(X)
    preds = np.argmax(output_eval, axis=-1)
    acc = np.mean(preds == y)
    return acc, transform_eval

# %% [markdown]
# # Training

# %%
np.set_printoptions(formatter={'float': '{: 0.4f}'.format}, suppress=True)
valid_accs, train_accs, test_accs = [], [], []
total_time = 0
param_outputs, disc_outputs = [], []
try:
    for n in range(NUM_EPOCHS):
        start_time = time.time()
        train_cost, train_acc, param_output, disc_output = train_epoch(data['X_train'], data['y_train'])
        valid_acc, valid_trainsform = eval_epoch(data['X_valid'], data['y_valid'])
        test_acc, test_transform = eval_epoch(data['X_test'], data['y_test'])
        valid_accs += [valid_acc]
        test_accs += [test_acc]
        train_accs += [train_acc]

        if DISC:
            param_outputs = np.append(param_outputs, param_output)
            disc_outputs = np.append(disc_outputs, disc_output)

        if (n+1) % 20 == 0:
            new_lr = sh_lr.get_value() * 0.99
            print "New LR:", new_lr
            sh_lr.set_value(lasagne.utils.floatX(new_lr))

        time_spent = time.time() - start_time
        total_time += time_spent
        print "Epoch {0}: T.cost {1:0.6f}, Train acc {2}, val acc {3}, test acc {4}, took {5:.3} sec.".format(
                n, train_cost, train_acc, valid_acc, test_acc, time_spent)

except KeyboardInterrupt:
    pass
print "\nTotal time spent: {0:.5} seconds\nTraing Acc: {1}\nTest Acc: {2}\nValidation Acc: {3}\n".format(total_time,
                                                                                                         train_acc,
                                                                                                         test_acc,
                                                                                                         valid_acc)
story = {'train_accs': train_accs,
         'test_accs': test_accs,
         'valid_accs': valid_accs,
         'epoch_reached': n, 
         'total_time': total_time,
         'disc_enabled': DISC,
         'learning_rate': LEARNING_RATE,
         'batch_size': BATCH_SIZE}                                                                                                         
with open('test_1_disc', 'wb') as fp:
  pickle.dump(story, fp)
# Out:
# Epoch 0: T.cost 1.829291, Train acc 0.34208, val acc 0.6113, test acc 0.6095, took 6.46 sec.
# Epoch 1: T.cost 0.919523, Train acc 0.7003, val acc 0.782, test acc 0.7787, took 6.49 sec.
# Epoch 2: T.cost 0.620998, Train acc 0.79848, val acc 0.8308, test acc 0.8307, took 6.36 sec.
# Epoch 3: T.cost 0.508660, Train acc 0.83522, val acc 0.8473, test acc 0.8444, took 6.45 sec.
# Epoch 4: T.cost 0.405451, Train acc 0.8692, val acc 0.8738, test acc 0.8732, took 6.45 sec.
# Epoch 5: T.cost 0.354288, Train acc 0.8866, val acc 0.8887, test acc 0.8908, took 6.45 sec.
# Epoch 6: T.cost 0.311703, Train acc 0.8994, val acc 0.8926, test acc 0.8911, took 6.48 sec.
# Epoch 7: T.cost 0.284468, Train acc 0.90844, val acc 0.906, test acc 0.9064, took 6.8 sec.
# Epoch 8: T.cost 0.254901, Train acc 0.9176, val acc 0.9201, test acc 0.9214, took 6.52 sec.
# Epoch 9: T.cost 0.233308, Train acc 0.92454, val acc 0.9202, test acc 0.9229, took 6.45 sec.
# Epoch 10: T.cost 0.217931, Train acc 0.92954, val acc 0.9217, test acc 0.9212, took 6.75 sec.
# Epoch 11: T.cost 0.212223, Train acc 0.93112, val acc 0.9295, test acc 0.9273, took 6.52 sec.
# Epoch 12: T.cost 0.188550, Train acc 0.93816, val acc 0.9348, test acc 0.937, took 6.49 sec.
# Epoch 13: T.cost 0.173892, Train acc 0.94346, val acc 0.9362, test acc 0.9361, took 6.76 sec.
# Epoch 14: T.cost 0.178863, Train acc 0.94148, val acc 0.9422, test acc 0.943, took 6.59 sec.
# Epoch 15: T.cost 0.166316, Train acc 0.94548, val acc 0.9388, test acc 0.9355, took 6.72 sec.
# Epoch 16: T.cost 0.155322, Train acc 0.94988, val acc 0.9455, test acc 0.9456, took 6.56 sec.
# Epoch 17: T.cost 0.146515, Train acc 0.95158, val acc 0.9456, test acc 0.9496, took 6.69 sec.
# Epoch 18: T.cost 0.142033, Train acc 0.9528, val acc 0.9464, test acc 0.9448, took 6.57 sec.
# New LR: 0.000990000047022
# Epoch 19: T.cost 0.142927, Train acc 0.9528, val acc 0.9383, test acc 0.9386, took 6.72 sec.
# Epoch 20: T.cost 0.130761, Train acc 0.95716, val acc 0.9501, test acc 0.9506, took 6.63 sec.
# Epoch 21: T.cost 0.125302, Train acc 0.958, val acc 0.9402, test acc 0.941, took 6.58 sec.
# Epoch 22: T.cost 0.126486, Train acc 0.95796, val acc 0.9438, test acc 0.946, took 6.68 sec.
# Epoch 23: T.cost 0.122566, Train acc 0.95888, val acc 0.9474, test acc 0.9474, took 6.62 sec.
# Epoch 24: T.cost 0.122041, Train acc 0.96066, val acc 0.9526, test acc 0.9548, took 7.18 sec.
# Epoch 25: T.cost 0.116645, Train acc 0.96132, val acc 0.9445, test acc 0.9437, took 6.29 sec.
# Epoch 26: T.cost 0.117215, Train acc 0.96148, val acc 0.9479, test acc 0.9482, took 6.6 sec.
# Epoch 27: T.cost 0.103454, Train acc 0.96628, val acc 0.9532, test acc 0.956, took 6.73 sec.
# Epoch 28: T.cost 0.109427, Train acc 0.96412, val acc 0.9552, test acc 0.951, took 6.84 sec.
# Epoch 29: T.cost 0.102670, Train acc 0.96652, val acc 0.958, test acc 0.9571, took 6.6 sec.
# Epoch 30: T.cost 0.094104, Train acc 0.9685, val acc 0.9581, test acc 0.954, took 6.58 sec.
# Epoch 31: T.cost 0.089702, Train acc 0.97034, val acc 0.9523, test acc 0.9543, took 6.67 sec.
# Epoch 32: T.cost 0.089600, Train acc 0.96988, val acc 0.9587, test acc 0.9616, took 6.6 sec.
# Epoch 33: T.cost 0.083855, Train acc 0.97254, val acc 0.9575, test acc 0.959, took 6.56 sec.
# Epoch 34: T.cost 0.084501, Train acc 0.97228, val acc 0.9513, test acc 0.9554, took 6.88 sec.
# Epoch 35: T.cost 0.084531, Train acc 0.97222, val acc 0.9599, test acc 0.9561, took 6.86 sec.
# Epoch 36: T.cost 0.084286, Train acc 0.97236, val acc 0.9592, test acc 0.9575, took 6.62 sec.
# Epoch 37: T.cost 0.080248, Train acc 0.97336, val acc 0.9585, test acc 0.9563, took 6.72 sec.
# Epoch 38: T.cost 0.080694, Train acc 0.97302, val acc 0.9607, test acc 0.9578, took 6.57 sec.
# New LR: 0.00098010008689
# Epoch 39: T.cost 0.079945, Train acc 0.97278, val acc 0.9598, test acc 0.9615, took 6.85 sec.
# Epoch 40: T.cost 0.075381, Train acc 0.97492, val acc 0.957, test acc 0.9606, took 6.65 sec.
# Epoch 41: T.cost 0.069759, Train acc 0.97654, val acc 0.9595, test acc 0.96, took 6.65 sec.
# Epoch 42: T.cost 0.063486, Train acc 0.97792, val acc 0.9611, test acc 0.9617, took 6.65 sec.
# Epoch 43: T.cost 0.070098, Train acc 0.97634, val acc 0.9585, test acc 0.9602, took 6.62 sec.
# Epoch 44: T.cost 0.072008, Train acc 0.97582, val acc 0.96, test acc 0.9598, took 6.67 sec.
# Epoch 45: T.cost 0.065650, Train acc 0.97798, val acc 0.9594, test acc 0.9634, took 6.63 sec.
# Epoch 46: T.cost 0.065228, Train acc 0.97766, val acc 0.9595, test acc 0.9606, took 6.86 sec.
# Epoch 47: T.cost 0.058767, Train acc 0.9807, val acc 0.9603, test acc 0.9579, took 6.53 sec.
# Epoch 48: T.cost 0.052528, Train acc 0.9824, val acc 0.9612, test acc 0.9614, took 6.7 sec.
# Epoch 49: T.cost 0.063416, Train acc 0.97904, val acc 0.9597, test acc 0.9597, took 6.74 sec.
# Epoch 50: T.cost 0.056254, Train acc 0.98092, val acc 0.9603, test acc 0.96, took 6.74 sec.
# Epoch 51: T.cost 0.054104, Train acc 0.98098, val acc 0.9626, test acc 0.9601, took 6.65 sec.
# Epoch 52: T.cost 0.059099, Train acc 0.97992, val acc 0.9571, test acc 0.9602, took 6.68 sec.
# Epoch 53: T.cost 0.054310, Train acc 0.98164, val acc 0.96, test acc 0.9607, took 6.76 sec.
# Epoch 54: T.cost 0.058847, Train acc 0.98028, val acc 0.957, test acc 0.9571, took 6.54 sec.
# Epoch 55: T.cost 0.051864, Train acc 0.98212, val acc 0.9583, test acc 0.9598, took 6.8 sec.
# Epoch 56: T.cost 0.058220, Train acc 0.98012, val acc 0.9616, test acc 0.9612, took 6.42 sec.
# Epoch 57: T.cost 0.056153, Train acc 0.98072, val acc 0.96, test acc 0.9599, took 6.07 sec.
# Epoch 58: T.cost 0.054607, Train acc 0.98138, val acc 0.9594, test acc 0.9589, took 6.09 sec.
# New LR: 0.000970299127512
# Epoch 59: T.cost 0.047230, Train acc 0.98386, val acc 0.9627, test acc 0.9619, took 6.08 sec.
# Epoch 60: T.cost 0.046198, Train acc 0.98472, val acc 0.9576, test acc 0.9593, took 6.38 sec.
# Epoch 61: T.cost 0.051523, Train acc 0.98264, val acc 0.9614, test acc 0.9594, took 6.18 sec.
# Epoch 62: T.cost 0.044303, Train acc 0.98458, val acc 0.9634, test acc 0.9652, took 6.18 sec.
# Epoch 63: T.cost 0.042118, Train acc 0.98516, val acc 0.9603, test acc 0.9614, took 6.08 sec.
# Epoch 64: T.cost 0.046457, Train acc 0.9847, val acc 0.9614, test acc 0.9585, took 6.09 sec.
# Epoch 65: T.cost 0.049643, Train acc 0.98326, val acc 0.9637, test acc 0.9639, took 6.1 sec.
# Epoch 66: T.cost 0.047342, Train acc 0.98446, val acc 0.9632, test acc 0.963, took 6.11 sec.
# Epoch 67: T.cost 0.044712, Train acc 0.98428, val acc 0.9579, test acc 0.9574, took 6.32 sec.
# Epoch 68: T.cost 0.048873, Train acc 0.98422, val acc 0.9588, test acc 0.9596, took 6.11 sec.
# Epoch 69: T.cost 0.041049, Train acc 0.98662, val acc 0.9633, test acc 0.9656, took 6.2 sec.
# Epoch 70: T.cost 0.044778, Train acc 0.98506, val acc 0.9629, test acc 0.9648, took 6.15 sec.
# Epoch 71: T.cost 0.037529, Train acc 0.98704, val acc 0.9583, test acc 0.958, took 6.11 sec.
# Epoch 72: T.cost 0.041404, Train acc 0.98586, val acc 0.9652, test acc 0.9649, took 6.11 sec.
# Epoch 73: T.cost 0.042986, Train acc 0.98518, val acc 0.9624, test acc 0.9621, took 6.09 sec.
# Epoch 74: T.cost 0.042863, Train acc 0.98574, val acc 0.9599, test acc 0.9619, took 6.06 sec.
# Epoch 75: T.cost 0.044167, Train acc 0.98558, val acc 0.9621, test acc 0.9621, took 6.21 sec.
# Epoch 76: T.cost 0.043393, Train acc 0.98582, val acc 0.959, test acc 0.9618, took 6.11 sec.
# Epoch 77: T.cost 0.037376, Train acc 0.98704, val acc 0.9587, test acc 0.9537, took 6.1 sec.
# Epoch 78: T.cost 0.034970, Train acc 0.98828, val acc 0.9577, test acc 0.9587, took 6.14 sec.
# New LR: 0.000960596131627
# Epoch 79: T.cost 0.037641, Train acc 0.98702, val acc 0.9601, test acc 0.9604, took 6.1 sec.
# Epoch 80: T.cost 0.033598, Train acc 0.98928, val acc 0.9566, test acc 0.9573, took 6.09 sec.
# Epoch 81: T.cost 0.044102, Train acc 0.9853, val acc 0.9606, test acc 0.9652, took 6.1 sec.
# Epoch 82: T.cost 0.035230, Train acc 0.9882, val acc 0.9576, test acc 0.9635, took 6.12 sec.
# Epoch 83: T.cost 0.031302, Train acc 0.98912, val acc 0.9619, test acc 0.9634, took 6.11 sec.
# Epoch 84: T.cost 0.032447, Train acc 0.98888, val acc 0.9619, test acc 0.9641, took 6.1 sec.
# Epoch 85: T.cost 0.028651, Train acc 0.98992, val acc 0.9646, test acc 0.9659, took 6.29 sec.
# Epoch 86: T.cost 0.040987, Train acc 0.9864, val acc 0.9634, test acc 0.9657, took 6.21 sec.
# Epoch 87: T.cost 0.029946, Train acc 0.9897, val acc 0.9611, test acc 0.9614, took 6.21 sec.
# Epoch 88: T.cost 0.040501, Train acc 0.98638, val acc 0.9622, test acc 0.9625, took 6.19 sec.
# Epoch 89: T.cost 0.032990, Train acc 0.98894, val acc 0.9606, test acc 0.9616, took 6.11 sec.
# Epoch 90: T.cost 0.035303, Train acc 0.98828, val acc 0.9648, test acc 0.9637, took 6.08 sec.
# Epoch 91: T.cost 0.033275, Train acc 0.98866, val acc 0.9687, test acc 0.9677, took 6.07 sec.
# Epoch 92: T.cost 0.034935, Train acc 0.98826, val acc 0.9685, test acc 0.9661, took 6.19 sec.
# Epoch 93: T.cost 0.030751, Train acc 0.98978, val acc 0.9604, test acc 0.9605, took 6.11 sec.
# Epoch 94: T.cost 0.032178, Train acc 0.98886, val acc 0.9634, test acc 0.964, took 6.12 sec.
# Epoch 95: T.cost 0.026703, Train acc 0.99146, val acc 0.9647, test acc 0.9637, took 6.12 sec.
# Epoch 96: T.cost 0.028150, Train acc 0.99034, val acc 0.9685, test acc 0.9682, took 6.15 sec.
# Epoch 97: T.cost 0.029997, Train acc 0.98954, val acc 0.9649, test acc 0.967, took 6.12 sec.
# Epoch 98: T.cost 0.025189, Train acc 0.99146, val acc 0.9577, test acc 0.9577, took 6.3 sec.
# New LR: 0.000950990177225
# Epoch 99: T.cost 0.038833, Train acc 0.98708, val acc 0.9612, test acc 0.9659, took 6.2 sec.
# Epoch 100: T.cost 0.028250, Train acc 0.99066, val acc 0.9629, test acc 0.9629, took 6.23 sec.
# Epoch 101: T.cost 0.037311, Train acc 0.98768, val acc 0.9622, test acc 0.963, took 6.22 sec.
# Epoch 102: T.cost 0.026807, Train acc 0.99062, val acc 0.967, test acc 0.9675, took 6.1 sec.
# Epoch 103: T.cost 0.026907, Train acc 0.9909, val acc 0.9624, test acc 0.965, took 6.22 sec.
# Epoch 104: T.cost 0.028201, Train acc 0.99042, val acc 0.9631, test acc 0.9662, took 6.11 sec.
# Epoch 105: T.cost 0.029305, Train acc 0.99026, val acc 0.9612, test acc 0.9612, took 6.22 sec.
# Epoch 106: T.cost 0.029305, Train acc 0.99044, val acc 0.9607, test acc 0.9632, took 6.13 sec.
# Epoch 107: T.cost 0.029119, Train acc 0.98986, val acc 0.9643, test acc 0.9654, took 6.14 sec.
# Epoch 108: T.cost 0.026588, Train acc 0.99148, val acc 0.9614, test acc 0.9624, took 6.16 sec.
# Epoch 109: T.cost 0.025426, Train acc 0.9918, val acc 0.9628, test acc 0.9624, took 6.14 sec.
# Epoch 110: T.cost 0.028666, Train acc 0.9908, val acc 0.966, test acc 0.967, took 6.13 sec.
# Epoch 111: T.cost 0.023881, Train acc 0.99184, val acc 0.9621, test acc 0.9637, took 6.14 sec.
# Epoch 112: T.cost 0.019988, Train acc 0.99354, val acc 0.9659, test acc 0.9673, took 6.14 sec.
# Epoch 113: T.cost 0.014442, Train acc 0.9951, val acc 0.967, test acc 0.9684, took 6.14 sec.
# Epoch 114: T.cost 0.030465, Train acc 0.98992, val acc 0.9619, test acc 0.9649, took 6.18 sec.
# Epoch 115: T.cost 0.024915, Train acc 0.99162, val acc 0.9623, test acc 0.9648, took 6.09 sec.
# Epoch 116: T.cost 0.023949, Train acc 0.99202, val acc 0.9627, test acc 0.9653, took 6.26 sec.
# Epoch 117: T.cost 0.022181, Train acc 0.99252, val acc 0.9661, test acc 0.9676, took 6.13 sec.
# Epoch 118: T.cost 0.020044, Train acc 0.993, val acc 0.9675, test acc 0.9671, took 6.14 sec.
# New LR: 0.000941480284673
# Epoch 119: T.cost 0.019169, Train acc 0.99384, val acc 0.9658, test acc 0.969, took 6.16 sec.
# Epoch 120: T.cost 0.021777, Train acc 0.99252, val acc 0.9667, test acc 0.9662, took 6.23 sec.
# Epoch 121: T.cost 0.022928, Train acc 0.99204, val acc 0.9632, test acc 0.9647, took 6.27 sec.
# Epoch 122: T.cost 0.018987, Train acc 0.99384, val acc 0.9606, test acc 0.9649, took 6.53 sec.
# Epoch 123: T.cost 0.021634, Train acc 0.99292, val acc 0.9654, test acc 0.9688, took 6.4 sec.
# Epoch 124: T.cost 0.033196, Train acc 0.98898, val acc 0.9642, test acc 0.9662, took 6.18 sec.
# Epoch 125: T.cost 0.018778, Train acc 0.9938, val acc 0.9648, test acc 0.9677, took 6.55 sec.
# Epoch 126: T.cost 0.028562, Train acc 0.99088, val acc 0.9615, test acc 0.9614, took 6.27 sec.
# Epoch 127: T.cost 0.019705, Train acc 0.99362, val acc 0.9623, test acc 0.9667, took 6.36 sec.
# Epoch 128: T.cost 0.025404, Train acc 0.99112, val acc 0.9623, test acc 0.964, took 6.25 sec.
# Epoch 129: T.cost 0.026714, Train acc 0.9908, val acc 0.9607, test acc 0.9654, took 6.26 sec.
# Epoch 130: T.cost 0.021980, Train acc 0.99256, val acc 0.9623, test acc 0.9624, took 6.21 sec.
# Epoch 131: T.cost 0.016831, Train acc 0.9946, val acc 0.9649, test acc 0.9695, took 6.17 sec.
# Epoch 132: T.cost 0.021998, Train acc 0.99278, val acc 0.9636, test acc 0.9651, took 6.53 sec.
# Epoch 133: T.cost 0.019386, Train acc 0.99372, val acc 0.965, test acc 0.9639, took 6.28 sec.
# Epoch 134: T.cost 0.027267, Train acc 0.99126, val acc 0.9621, test acc 0.9661, took 6.27 sec.
# Epoch 135: T.cost 0.023184, Train acc 0.99162, val acc 0.9646, test acc 0.9684, took 6.41 sec.
# Epoch 136: T.cost 0.018760, Train acc 0.99384, val acc 0.9652, test acc 0.9641, took 6.24 sec.
# Epoch 137: T.cost 0.018744, Train acc 0.99382, val acc 0.9668, test acc 0.9669, took 6.38 sec.
# Epoch 138: T.cost 0.020433, Train acc 0.9929, val acc 0.965, test acc 0.9661, took 6.18 sec.
# New LR: 0.000932065474335
# Epoch 139: T.cost 0.025086, Train acc 0.99176, val acc 0.966, test acc 0.9676, took 6.53 sec.
# Epoch 140: T.cost 0.023919, Train acc 0.9921, val acc 0.9584, test acc 0.9603, took 6.29 sec.
# Epoch 141: T.cost 0.023672, Train acc 0.99234, val acc 0.9668, test acc 0.9675, took 6.29 sec.
# Epoch 142: T.cost 0.025439, Train acc 0.99152, val acc 0.9609, test acc 0.9659, took 6.3 sec.
# Epoch 143: T.cost 0.025121, Train acc 0.99142, val acc 0.9667, test acc 0.9669, took 6.27 sec.
# Epoch 144: T.cost 0.015784, Train acc 0.99436, val acc 0.9668, test acc 0.9658, took 6.48 sec.
# Epoch 145: T.cost 0.020082, Train acc 0.99364, val acc 0.9646, test acc 0.9668, took 6.2 sec.
# Epoch 146: T.cost 0.021847, Train acc 0.99264, val acc 0.9675, test acc 0.9671, took 6.55 sec.
# Epoch 147: T.cost 0.017699, Train acc 0.99444, val acc 0.967, test acc 0.9677, took 6.26 sec.
# Epoch 148: T.cost 0.020192, Train acc 0.99308, val acc 0.9631, test acc 0.965, took 6.29 sec.
# Epoch 149: T.cost 0.015104, Train acc 0.99468, val acc 0.9653, test acc 0.9665, took 6.3 sec.
# Epoch 150: T.cost 0.019237, Train acc 0.99366, val acc 0.9624, test acc 0.9628, took 6.27 sec.
# Epoch 151: T.cost 0.021469, Train acc 0.99252, val acc 0.9612, test acc 0.9617, took 6.28 sec.
# Epoch 152: T.cost 0.017669, Train acc 0.99402, val acc 0.9656, test acc 0.966, took 6.3 sec.
# Epoch 153: T.cost 0.019548, Train acc 0.99314, val acc 0.9675, test acc 0.9697, took 6.75 sec.
# Epoch 154: T.cost 0.013698, Train acc 0.99544, val acc 0.9656, test acc 0.9693, took 6.92 sec.
# Epoch 155: T.cost 0.013715, Train acc 0.99548, val acc 0.9681, test acc 0.9696, took 6.33 sec.
# Epoch 156: T.cost 0.021690, Train acc 0.99274, val acc 0.9639, test acc 0.9645, took 7.22 sec.
# Epoch 157: T.cost 0.021245, Train acc 0.9923, val acc 0.9655, test acc 0.965, took 6.66 sec.
# Epoch 158: T.cost 0.015675, Train acc 0.99452, val acc 0.967, test acc 0.9665, took 6.37 sec.
# New LR: 0.000922744824202
# Epoch 159: T.cost 0.016108, Train acc 0.99468, val acc 0.9666, test acc 0.9669, took 6.39 sec.
# Epoch 160: T.cost 0.018599, Train acc 0.99374, val acc 0.9681, test acc 0.9655, took 6.54 sec.
# Epoch 161: T.cost 0.016562, Train acc 0.99414, val acc 0.9662, test acc 0.9659, took 6.69 sec.
# Epoch 162: T.cost 0.017953, Train acc 0.99428, val acc 0.9617, test acc 0.9641, took 6.47 sec.
# Epoch 163: T.cost 0.018531, Train acc 0.99358, val acc 0.9639, test acc 0.965, took 6.61 sec.
# Epoch 164: T.cost 0.021108, Train acc 0.99292, val acc 0.9643, test acc 0.9673, took 6.5 sec.
# Epoch 165: T.cost 0.017049, Train acc 0.9941, val acc 0.9649, test acc 0.9669, took 6.86 sec.
# Epoch 166: T.cost 0.013579, Train acc 0.9956, val acc 0.9663, test acc 0.967, took 7.49 sec.
# Epoch 167: T.cost 0.014870, Train acc 0.99512, val acc 0.9665, test acc 0.9678, took 6.44 sec.
# Epoch 168: T.cost 0.015801, Train acc 0.99448, val acc 0.9676, test acc 0.9659, took 7.07 sec.
# Epoch 169: T.cost 0.019042, Train acc 0.99344, val acc 0.9634, test acc 0.965, took 6.62 sec.
# Epoch 170: T.cost 0.020508, Train acc 0.9931, val acc 0.9649, test acc 0.9679, took 6.36 sec.
# Epoch 171: T.cost 0.013515, Train acc 0.99558, val acc 0.9638, test acc 0.964, took 6.51 sec.
# Epoch 172: T.cost 0.013072, Train acc 0.9955, val acc 0.9626, test acc 0.9677, took 6.39 sec.
# Epoch 173: T.cost 0.020112, Train acc 0.99352, val acc 0.9651, test acc 0.9649, took 7.24 sec.
# Epoch 174: T.cost 0.023287, Train acc 0.9922, val acc 0.9633, test acc 0.9632, took 6.64 sec.
# Epoch 175: T.cost 0.015241, Train acc 0.99458, val acc 0.9666, test acc 0.967, took 6.68 sec.
# Epoch 176: T.cost 0.013268, Train acc 0.99594, val acc 0.9683, test acc 0.9669, took 6.4 sec.
# Epoch 177: T.cost 0.012549, Train acc 0.99582, val acc 0.964, test acc 0.9661, took 7.02 sec.
# Epoch 178: T.cost 0.021460, Train acc 0.99298, val acc 0.9617, test acc 0.9637, took 6.49 sec.
# New LR: 0.000913517354638
# Epoch 179: T.cost 0.018236, Train acc 0.99404, val acc 0.9636, test acc 0.9661, took 6.68 sec.
# Epoch 180: T.cost 0.017442, Train acc 0.99442, val acc 0.9676, test acc 0.9673, took 6.96 sec.
# Epoch 181: T.cost 0.013875, Train acc 0.99534, val acc 0.9654, test acc 0.9629, took 6.46 sec.
# Epoch 182: T.cost 0.018424, Train acc 0.9942, val acc 0.965, test acc 0.9681, took 6.6 sec.
# Epoch 183: T.cost 0.016480, Train acc 0.99432, val acc 0.967, test acc 0.9669, took 6.48 sec.
# Epoch 184: T.cost 0.015461, Train acc 0.99432, val acc 0.9674, test acc 0.967, took 6.74 sec.
# Epoch 185: T.cost 0.012072, Train acc 0.99584, val acc 0.965, test acc 0.967, took 6.84 sec.
# Epoch 186: T.cost 0.016721, Train acc 0.9947, val acc 0.9645, test acc 0.9642, took 6.83 sec.
# Epoch 187: T.cost 0.017475, Train acc 0.99438, val acc 0.9676, test acc 0.964, took 6.51 sec.
# Epoch 188: T.cost 0.023589, Train acc 0.99266, val acc 0.9611, test acc 0.9633, took 6.56 sec.
# Epoch 189: T.cost 0.018266, Train acc 0.994, val acc 0.966, test acc 0.9665, took 6.74 sec.
# Epoch 190: T.cost 0.014720, Train acc 0.99528, val acc 0.9627, test acc 0.9678, took 6.58 sec.
# Epoch 191: T.cost 0.017552, Train acc 0.99428, val acc 0.9666, test acc 0.9641, took 7.01 sec.
# Epoch 192: T.cost 0.011635, Train acc 0.99616, val acc 0.9654, test acc 0.9706, took 6.95 sec.
# Epoch 193: T.cost 0.012789, Train acc 0.99588, val acc 0.967, test acc 0.9688, took 6.42 sec.
# Epoch 194: T.cost 0.012601, Train acc 0.99574, val acc 0.9666, test acc 0.9698, took 6.4 sec.
# Epoch 195: T.cost 0.015282, Train acc 0.99462, val acc 0.9668, test acc 0.9662, took 6.57 sec.
# Epoch 196: T.cost 0.013747, Train acc 0.9956, val acc 0.9593, test acc 0.9619, took 6.97 sec.
# Epoch 197: T.cost 0.032697, Train acc 0.9909, val acc 0.9572, test acc 0.9602, took 6.86 sec.
# Epoch 198: T.cost 0.022775, Train acc 0.99256, val acc 0.9645, test acc 0.9651, took 6.42 sec.
# New LR: 0.000904382201261
# Epoch 199: T.cost 0.011699, Train acc 0.99614, val acc 0.969, test acc 0.9676, took 6.39 sec.
# Epoch 200: T.cost 0.012043, Train acc 0.99574, val acc 0.9655, test acc 0.9693, took 6.35 sec.
# Epoch 201: T.cost 0.013180, Train acc 0.99562, val acc 0.9654, test acc 0.9657, took 7.47 sec.
# Epoch 202: T.cost 0.009512, Train acc 0.99688, val acc 0.9671, test acc 0.9679, took 6.78 sec.
# Epoch 203: T.cost 0.014462, Train acc 0.9952, val acc 0.9655, test acc 0.9679, took 6.46 sec.
# Epoch 204: T.cost 0.013527, Train acc 0.99554, val acc 0.9656, test acc 0.9691, took 6.4 sec.
# Epoch 205: T.cost 0.012129, Train acc 0.99578, val acc 0.9647, test acc 0.9643, took 6.43 sec.
# Epoch 206: T.cost 0.016231, Train acc 0.9947, val acc 0.9659, test acc 0.9676, took 6.83 sec.
# Epoch 207: T.cost 0.011578, Train acc 0.99612, val acc 0.9677, test acc 0.9679, took 6.63 sec.
# Epoch 208: T.cost 0.017697, Train acc 0.99418, val acc 0.9591, test acc 0.9572, took 6.45 sec.
# Epoch 209: T.cost 0.025350, Train acc 0.99184, val acc 0.968, test acc 0.967, took 6.64 sec.
# Epoch 210: T.cost 0.012294, Train acc 0.99608, val acc 0.968, test acc 0.9671, took 6.85 sec.
# Epoch 211: T.cost 0.010927, Train acc 0.99664, val acc 0.9692, test acc 0.9666, took 6.61 sec.
# Epoch 212: T.cost 0.007028, Train acc 0.99758, val acc 0.9691, test acc 0.9684, took 6.45 sec.
# Epoch 213: T.cost 0.008607, Train acc 0.99718, val acc 0.9684, test acc 0.9665, took 6.29 sec.
# Epoch 214: T.cost 0.021602, Train acc 0.993, val acc 0.9611, test acc 0.9619, took 6.37 sec.
# Epoch 215: T.cost 0.015505, Train acc 0.99502, val acc 0.9659, test acc 0.9636, took 6.33 sec.
# Epoch 216: T.cost 0.022050, Train acc 0.993, val acc 0.9631, test acc 0.9611, took 6.39 sec.
# Epoch 217: T.cost 0.018516, Train acc 0.99396, val acc 0.9662, test acc 0.9662, took 6.4 sec.
# Epoch 218: T.cost 0.012436, Train acc 0.99542, val acc 0.9671, test acc 0.9642, took 6.13 sec.
# New LR: 0.000895338384435
# Epoch 219: T.cost 0.020951, Train acc 0.99336, val acc 0.9676, test acc 0.966, took 6.86 sec.
# Epoch 220: T.cost 0.012396, Train acc 0.99572, val acc 0.9669, test acc 0.9698, took 6.63 sec.
# Epoch 221: T.cost 0.018845, Train acc 0.9937, val acc 0.9653, test acc 0.9648, took 6.54 sec.
# Epoch 222: T.cost 0.014845, Train acc 0.99506, val acc 0.9654, test acc 0.9661, took 6.42 sec.
# Epoch 223: T.cost 0.012912, Train acc 0.9954, val acc 0.966, test acc 0.9669, took 6.83 sec.
# Epoch 224: T.cost 0.010829, Train acc 0.99646, val acc 0.9677, test acc 0.9695, took 6.11 sec.
# Epoch 225: T.cost 0.008384, Train acc 0.99716, val acc 0.9661, test acc 0.9667, took 6.67 sec.
# Epoch 226: T.cost 0.010753, Train acc 0.99612, val acc 0.9645, test acc 0.9655, took 6.49 sec.
# Epoch 227: T.cost 0.014721, Train acc 0.99496, val acc 0.9687, test acc 0.967, took 6.09 sec.
# Epoch 228: T.cost 0.013255, Train acc 0.9958, val acc 0.9651, test acc 0.9649, took 6.13 sec.
# Epoch 229: T.cost 0.026641, Train acc 0.99174, val acc 0.9665, test acc 0.9673, took 6.33 sec.
# Epoch 230: T.cost 0.016784, Train acc 0.9944, val acc 0.9697, test acc 0.9675, took 6.66 sec.
# Epoch 231: T.cost 0.014819, Train acc 0.99538, val acc 0.9674, test acc 0.9687, took 6.51 sec.
# Epoch 232: T.cost 0.016858, Train acc 0.99432, val acc 0.9662, test acc 0.9689, took 6.21 sec.
# Epoch 233: T.cost 0.014178, Train acc 0.99488, val acc 0.9682, test acc 0.9682, took 6.97 sec.
# Epoch 234: T.cost 0.014730, Train acc 0.99476, val acc 0.9669, test acc 0.969, took 6.54 sec.
# Epoch 235: T.cost 0.009530, Train acc 0.99672, val acc 0.9656, test acc 0.9667, took 6.2 sec.
# Epoch 236: T.cost 0.008992, Train acc 0.99696, val acc 0.968, test acc 0.9681, took 6.29 sec.
# Epoch 237: T.cost 0.008285, Train acc 0.9973, val acc 0.9685, test acc 0.966, took 6.08 sec.
# Epoch 238: T.cost 0.011267, Train acc 0.99624, val acc 0.965, test acc 0.9674, took 6.53 sec.
# New LR: 0.00088638498215
# Epoch 239: T.cost 0.010490, Train acc 0.99678, val acc 0.9666, test acc 0.968, took 6.56 sec.
# Epoch 240: T.cost 0.018414, Train acc 0.99414, val acc 0.9673, test acc 0.9698, took 6.13 sec.
# Epoch 241: T.cost 0.011476, Train acc 0.99634, val acc 0.9668, test acc 0.9681, took 6.22 sec.
# Epoch 242: T.cost 0.009319, Train acc 0.99674, val acc 0.9693, test acc 0.9701, took 6.21 sec.
# Epoch 243: T.cost 0.009116, Train acc 0.99714, val acc 0.9685, test acc 0.9694, took 6.49 sec.
# Epoch 244: T.cost 0.009367, Train acc 0.99678, val acc 0.9641, test acc 0.9658, took 6.22 sec.
# Epoch 245: T.cost 0.017202, Train acc 0.99398, val acc 0.9671, test acc 0.9666, took 6.92 sec.
# Epoch 246: T.cost 0.010722, Train acc 0.99616, val acc 0.9653, test acc 0.9641, took 7.33 sec.
# Epoch 247: T.cost 0.011042, Train acc 0.9962, val acc 0.9673, test acc 0.9661, took 6.86 sec.
# Epoch 248: T.cost 0.007920, Train acc 0.99732, val acc 0.9673, test acc 0.9691, took 7.44 sec.
# Epoch 249: T.cost 0.009038, Train acc 0.99686, val acc 0.9675, test acc 0.9649, took 7.11 sec.
# Epoch 250: T.cost 0.011514, Train acc 0.99626, val acc 0.9684, test acc 0.9679, took 6.14 sec.
# Epoch 251: T.cost 0.014113, Train acc 0.9957, val acc 0.9627, test acc 0.9687, took 6.13 sec.
# Epoch 252: T.cost 0.025543, Train acc 0.99214, val acc 0.9662, test acc 0.9688, took 6.42 sec.
# Epoch 253: T.cost 0.016737, Train acc 0.9948, val acc 0.9636, test acc 0.9673, took 6.32 sec.
# Epoch 254: T.cost 0.009947, Train acc 0.99674, val acc 0.9673, test acc 0.9705, took 6.24 sec.
# Epoch 255: T.cost 0.007216, Train acc 0.99746, val acc 0.9674, test acc 0.9727, took 6.24 sec.
# Epoch 256: T.cost 0.009919, Train acc 0.99676, val acc 0.9662, test acc 0.9686, took 6.16 sec.
# Epoch 257: T.cost 0.012512, Train acc 0.99634, val acc 0.9648, test acc 0.9676, took 6.08 sec.
# Epoch 258: T.cost 0.029462, Train acc 0.99158, val acc 0.964, test acc 0.9649, took 6.06 sec.
# New LR: 0.000877521130024
# Epoch 259: T.cost 0.017240, Train acc 0.99412, val acc 0.9679, test acc 0.9677, took 6.31 sec.
# Epoch 260: T.cost 0.018977, Train acc 0.99372, val acc 0.9647, test acc 0.9623, took 6.14 sec.
# Epoch 261: T.cost 0.010837, Train acc 0.99648, val acc 0.966, test acc 0.9643, took 6.16 sec.
# Epoch 262: T.cost 0.014692, Train acc 0.9953, val acc 0.9635, test acc 0.9671, took 6.18 sec.
# Epoch 263: T.cost 0.007485, Train acc 0.99772, val acc 0.9667, test acc 0.97, took 6.28 sec.
# Epoch 264: T.cost 0.010565, Train acc 0.99652, val acc 0.9674, test acc 0.9695, took 6.91 sec.
# Epoch 265: T.cost 0.009216, Train acc 0.99692, val acc 0.9678, test acc 0.9707, took 7.46 sec.
# Epoch 266: T.cost 0.008660, Train acc 0.99726, val acc 0.9676, test acc 0.9688, took 7.22 sec.
# Epoch 267: T.cost 0.010388, Train acc 0.99652, val acc 0.9679, test acc 0.9691, took 7.63 sec.
# Epoch 268: T.cost 0.008504, Train acc 0.99722, val acc 0.968, test acc 0.9686, took 6.85 sec.
# Epoch 269: T.cost 0.008058, Train acc 0.997, val acc 0.9662, test acc 0.9685, took 6.14 sec.
# Epoch 270: T.cost 0.010167, Train acc 0.99664, val acc 0.9657, test acc 0.9674, took 6.09 sec.
# Epoch 271: T.cost 0.017213, Train acc 0.99462, val acc 0.9623, test acc 0.9635, took 6.35 sec.
# Epoch 272: T.cost 0.014313, Train acc 0.99542, val acc 0.9684, test acc 0.9694, took 6.09 sec.
# Epoch 273: T.cost 0.016344, Train acc 0.9951, val acc 0.968, test acc 0.97, took 6.35 sec.
# Epoch 274: T.cost 0.012610, Train acc 0.99602, val acc 0.9652, test acc 0.9668, took 6.21 sec.
# Epoch 275: T.cost 0.014200, Train acc 0.99532, val acc 0.9651, test acc 0.9659, took 6.25 sec.
# Epoch 276: T.cost 0.007031, Train acc 0.99768, val acc 0.9669, test acc 0.9678, took 6.21 sec.
# Epoch 277: T.cost 0.016206, Train acc 0.99454, val acc 0.9631, test acc 0.9662, took 6.19 sec.
# Epoch 278: T.cost 0.016636, Train acc 0.99506, val acc 0.967, test acc 0.9683, took 6.18 sec.
# New LR: 0.000868745906046
# Epoch 279: T.cost 0.010347, Train acc 0.9964, val acc 0.97, test acc 0.9677, took 6.17 sec.
# Epoch 280: T.cost 0.005924, Train acc 0.99802, val acc 0.9677, test acc 0.9671, took 6.19 sec.
# Epoch 281: T.cost 0.008115, Train acc 0.99726, val acc 0.967, test acc 0.9679, took 6.21 sec.
# Epoch 282: T.cost 0.011639, Train acc 0.99588, val acc 0.967, test acc 0.9698, took 6.81 sec.
# Epoch 283: T.cost 0.010681, Train acc 0.99654, val acc 0.9701, test acc 0.9698, took 7.14 sec.
# Epoch 284: T.cost 0.005152, Train acc 0.99826, val acc 0.9681, test acc 0.9713, took 6.91 sec.
# Epoch 285: T.cost 0.007050, Train acc 0.9978, val acc 0.9669, test acc 0.9669, took 7.18 sec.
# Epoch 286: T.cost 0.009643, Train acc 0.99718, val acc 0.9658, test acc 0.967, took 7.16 sec.
# Epoch 287: T.cost 0.008636, Train acc 0.99694, val acc 0.9657, test acc 0.9703, took 6.31 sec.
# Epoch 288: T.cost 0.009259, Train acc 0.99706, val acc 0.9658, test acc 0.9655, took 6.22 sec.
# Epoch 289: T.cost 0.018498, Train acc 0.99408, val acc 0.9649, test acc 0.9665, took 6.19 sec.
# Epoch 290: T.cost 0.011249, Train acc 0.99632, val acc 0.9657, test acc 0.9676, took 6.18 sec.
# Epoch 291: T.cost 0.009609, Train acc 0.99668, val acc 0.9693, test acc 0.9685, took 6.15 sec.
# Epoch 292: T.cost 0.006470, Train acc 0.99764, val acc 0.9689, test acc 0.9684, took 6.15 sec.
# Epoch 293: T.cost 0.006903, Train acc 0.99774, val acc 0.9703, test acc 0.968, took 6.37 sec.
# Epoch 294: T.cost 0.007156, Train acc 0.99774, val acc 0.9671, test acc 0.9676, took 6.16 sec.
# Epoch 295: T.cost 0.008021, Train acc 0.99732, val acc 0.9662, test acc 0.9688, took 6.18 sec.
# Epoch 296: T.cost 0.048966, Train acc 0.98656, val acc 0.9627, test acc 0.9667, took 6.2 sec.
# Epoch 297: T.cost 0.017510, Train acc 0.99424, val acc 0.9655, test acc 0.966, took 6.2 sec.
# Epoch 298: T.cost 0.007062, Train acc 0.9975, val acc 0.9682, test acc 0.9669, took 6.17 sec.
# New LR: 0.000860058445833
# Epoch 299: T.cost 0.005604, Train acc 0.9982, val acc 0.9713, test acc 0.9711, took 6.23 sec.
# Epoch 300: T.cost 0.006658, Train acc 0.9979, val acc 0.9673, test acc 0.9693, took 6.31 sec.
# Epoch 301: T.cost 0.008330, Train acc 0.99708, val acc 0.9679, test acc 0.9659, took 7.27 sec.
# Epoch 302: T.cost 0.005792, Train acc 0.99814, val acc 0.97, test acc 0.9672, took 7.31 sec.
# Epoch 303: T.cost 0.018025, Train acc 0.99424, val acc 0.9656, test acc 0.966, took 7.14 sec.
# Epoch 304: T.cost 0.008698, Train acc 0.99696, val acc 0.9634, test acc 0.967, took 6.86 sec.
# Epoch 305: T.cost 0.006396, Train acc 0.99778, val acc 0.9621, test acc 0.9661, took 6.96 sec.
# Epoch 306: T.cost 0.006713, Train acc 0.99772, val acc 0.9655, test acc 0.9687, took 6.19 sec.
# Epoch 307: T.cost 0.006533, Train acc 0.99772, val acc 0.9657, test acc 0.9676, took 6.21 sec.
# Epoch 308: T.cost 0.010714, Train acc 0.99636, val acc 0.9677, test acc 0.966, took 6.19 sec.
# Epoch 309: T.cost 0.008546, Train acc 0.99718, val acc 0.967, test acc 0.9683, took 6.2 sec.
# Epoch 310: T.cost 0.011223, Train acc 0.99636, val acc 0.965, test acc 0.9619, took 6.2 sec.
# Epoch 311: T.cost 0.017238, Train acc 0.99482, val acc 0.9669, test acc 0.9678, took 6.2 sec.
# Epoch 312: T.cost 0.012468, Train acc 0.99584, val acc 0.9637, test acc 0.9665, took 6.21 sec.
# Epoch 313: T.cost 0.011491, Train acc 0.99608, val acc 0.9667, test acc 0.9662, took 6.19 sec.
# Epoch 314: T.cost 0.004544, Train acc 0.99844, val acc 0.967, test acc 0.9707, took 6.2 sec.
# Epoch 315: T.cost 0.005802, Train acc 0.99824, val acc 0.9649, test acc 0.9686, took 6.21 sec.
# Epoch 316: T.cost 0.011818, Train acc 0.99608, val acc 0.9674, test acc 0.9677, took 6.22 sec.
# Epoch 317: T.cost 0.012505, Train acc 0.99616, val acc 0.9641, test acc 0.9665, took 6.19 sec.
# Epoch 318: T.cost 0.010321, Train acc 0.99652, val acc 0.9688, test acc 0.968, took 6.17 sec.
# New LR: 0.000851457885001
# Epoch 319: T.cost 0.006633, Train acc 0.99774, val acc 0.9665, test acc 0.9686, took 6.34 sec.
# Epoch 320: T.cost 0.006891, Train acc 0.99758, val acc 0.9672, test acc 0.9648, took 7.49 sec.
# Epoch 321: T.cost 0.004450, Train acc 0.9985, val acc 0.9689, test acc 0.9695, took 7.26 sec.
# Epoch 322: T.cost 0.008899, Train acc 0.99718, val acc 0.9674, test acc 0.9695, took 7.6 sec.
# Epoch 323: T.cost 0.011649, Train acc 0.99626, val acc 0.9688, test acc 0.9673, took 7.05 sec.
# Epoch 324: T.cost 0.009518, Train acc 0.9969, val acc 0.9675, test acc 0.9689, took 6.5 sec.
# Epoch 325: T.cost 0.014542, Train acc 0.99534, val acc 0.9679, test acc 0.9664, took 6.4 sec.
# Epoch 326: T.cost 0.019129, Train acc 0.99412, val acc 0.9669, test acc 0.9638, took 6.2 sec.
# Epoch 327: T.cost 0.010801, Train acc 0.9969, val acc 0.9662, test acc 0.9659, took 6.22 sec.
# Epoch 328: T.cost 0.007140, Train acc 0.9977, val acc 0.969, test acc 0.968, took 6.23 sec.
# Epoch 329: T.cost 0.005959, Train acc 0.9979, val acc 0.9668, test acc 0.9685, took 6.22 sec.
# Epoch 330: T.cost 0.008744, Train acc 0.99744, val acc 0.9672, test acc 0.9661, took 6.19 sec.
# Epoch 331: T.cost 0.012246, Train acc 0.99638, val acc 0.967, test acc 0.9655, took 6.14 sec.
# Epoch 332: T.cost 0.011727, Train acc 0.99654, val acc 0.9684, test acc 0.9678, took 6.42 sec.
# Epoch 333: T.cost 0.004741, Train acc 0.99832, val acc 0.9678, test acc 0.9669, took 6.23 sec.
# Epoch 334: T.cost 0.010625, Train acc 0.9965, val acc 0.9665, test acc 0.9679, took 6.25 sec.
# Epoch 335: T.cost 0.014365, Train acc 0.99548, val acc 0.9675, test acc 0.9667, took 6.28 sec.
# Epoch 336: T.cost 0.012425, Train acc 0.99602, val acc 0.9634, test acc 0.9632, took 6.22 sec.
# Epoch 337: T.cost 0.010115, Train acc 0.99696, val acc 0.966, test acc 0.9651, took 6.65 sec.
# Epoch 338: T.cost 0.005542, Train acc 0.99822, val acc 0.9701, test acc 0.9685, took 6.82 sec.
# New LR: 0.000842943301541
# Epoch 339: T.cost 0.008619, Train acc 0.99722, val acc 0.9665, test acc 0.965, took 6.91 sec.
# Epoch 340: T.cost 0.017430, Train acc 0.99484, val acc 0.9689, test acc 0.9659, took 6.93 sec.
# Epoch 341: T.cost 0.016827, Train acc 0.99484, val acc 0.9669, test acc 0.9657, took 6.76 sec.
# Epoch 342: T.cost 0.015095, Train acc 0.99568, val acc 0.9669, test acc 0.9661, took 6.97 sec.
# Epoch 343: T.cost 0.009644, Train acc 0.99686, val acc 0.9671, test acc 0.9696, took 6.86 sec.
# Epoch 344: T.cost 0.008308, Train acc 0.99738, val acc 0.9691, test acc 0.9664, took 6.98 sec.
# Epoch 345: T.cost 0.007286, Train acc 0.99748, val acc 0.9685, test acc 0.9664, took 6.85 sec.
# Epoch 346: T.cost 0.012499, Train acc 0.99642, val acc 0.9677, test acc 0.9672, took 6.87 sec.
# Epoch 347: T.cost 0.013187, Train acc 0.99588, val acc 0.9657, test acc 0.9628, took 6.92 sec.
# Epoch 348: T.cost 0.010419, Train acc 0.9966, val acc 0.9695, test acc 0.9693, took 7.03 sec.
# Epoch 349: T.cost 0.013897, Train acc 0.99562, val acc 0.9671, test acc 0.9661, took 6.86 sec.
# Epoch 350: T.cost 0.006660, Train acc 0.99758, val acc 0.9682, test acc 0.9693, took 6.78 sec.
# Epoch 351: T.cost 0.008576, Train acc 0.99716, val acc 0.9662, test acc 0.9666, took 6.82 sec.
# Epoch 352: T.cost 0.006899, Train acc 0.99756, val acc 0.9676, test acc 0.9663, took 7.38 sec.
# Epoch 353: T.cost 0.006488, Train acc 0.99774, val acc 0.9661, test acc 0.965, took 6.96 sec.
# Epoch 354: T.cost 0.005888, Train acc 0.99814, val acc 0.9706, test acc 0.9689, took 6.94 sec.
# Epoch 355: T.cost 0.016591, Train acc 0.99544, val acc 0.9633, test acc 0.9609, took 6.82 sec.
# Epoch 356: T.cost 0.015475, Train acc 0.9948, val acc 0.9682, test acc 0.9701, took 7.06 sec.
# Epoch 357: T.cost 0.009187, Train acc 0.99694, val acc 0.9674, test acc 0.9663, took 6.9 sec.
# Epoch 358: T.cost 0.006463, Train acc 0.99812, val acc 0.9677, test acc 0.968, took 6.91 sec.
# New LR: 0.000834513888694
# Epoch 359: T.cost 0.006894, Train acc 0.99762, val acc 0.9692, test acc 0.9662, took 6.86 sec.
# Epoch 360: T.cost 0.005839, Train acc 0.9982, val acc 0.9685, test acc 0.9675, took 6.89 sec.
# Epoch 361: T.cost 0.004830, Train acc 0.99834, val acc 0.9705, test acc 0.9706, took 6.88 sec.
# Epoch 362: T.cost 0.006635, Train acc 0.99788, val acc 0.9678, test acc 0.9689, took 6.68 sec.
# Epoch 363: T.cost 0.028048, Train acc 0.9917, val acc 0.9628, test acc 0.9634, took 6.8 sec.
# Epoch 364: T.cost 0.014122, Train acc 0.99562, val acc 0.9652, test acc 0.9646, took 7.02 sec.
# Epoch 365: T.cost 0.006341, Train acc 0.99804, val acc 0.968, test acc 0.9702, took 6.82 sec.
# Epoch 366: T.cost 0.005728, Train acc 0.99796, val acc 0.9693, test acc 0.968, took 6.84 sec.
# Epoch 367: T.cost 0.005252, Train acc 0.99838, val acc 0.9666, test acc 0.9658, took 6.81 sec.
# Epoch 368: T.cost 0.003991, Train acc 0.99882, val acc 0.9687, test acc 0.9682, took 6.85 sec.
# Epoch 369: T.cost 0.008877, Train acc 0.99712, val acc 0.9686, test acc 0.9667, took 7.04 sec.
# Epoch 370: T.cost 0.008121, Train acc 0.9972, val acc 0.9703, test acc 0.97, took 6.99 sec.
# Epoch 371: T.cost 0.010963, Train acc 0.9966, val acc 0.9655, test acc 0.9668, took 6.66 sec.
# Epoch 372: T.cost 0.007563, Train acc 0.99764, val acc 0.9654, test acc 0.9665, took 6.81 sec.
# Epoch 373: T.cost 0.007201, Train acc 0.99764, val acc 0.9682, test acc 0.9669, took 7.07 sec.
# Epoch 374: T.cost 0.007660, Train acc 0.99756, val acc 0.9673, test acc 0.9667, took 6.87 sec.
# Epoch 375: T.cost 0.016583, Train acc 0.99504, val acc 0.9698, test acc 0.9704, took 6.96 sec.
# Epoch 376: T.cost 0.009062, Train acc 0.99702, val acc 0.9688, test acc 0.9684, took 6.95 sec.
# Epoch 377: T.cost 0.008249, Train acc 0.99742, val acc 0.9661, test acc 0.9665, took 6.9 sec.
# Epoch 378: T.cost 0.006724, Train acc 0.99816, val acc 0.9694, test acc 0.9704, took 6.86 sec.
# New LR: 0.000826168724452
# Epoch 379: T.cost 0.004020, Train acc 0.99866, val acc 0.9692, test acc 0.9689, took 6.95 sec.
# Epoch 380: T.cost 0.008746, Train acc 0.99714, val acc 0.9681, test acc 0.9675, took 6.94 sec.
# Epoch 381: T.cost 0.006605, Train acc 0.9977, val acc 0.9686, test acc 0.9681, took 6.98 sec.
# Epoch 382: T.cost 0.012531, Train acc 0.99594, val acc 0.9655, test acc 0.9683, took 6.85 sec.
# Epoch 383: T.cost 0.009176, Train acc 0.99684, val acc 0.9687, test acc 0.9676, took 6.84 sec.
# Epoch 384: T.cost 0.005541, Train acc 0.99818, val acc 0.9675, test acc 0.966, took 6.76 sec.
# Epoch 385: T.cost 0.009049, Train acc 0.9969, val acc 0.9668, test acc 0.9679, took 6.84 sec.
# Epoch 386: T.cost 0.010169, Train acc 0.99696, val acc 0.9651, test acc 0.9656, took 6.88 sec.
# Epoch 387: T.cost 0.012656, Train acc 0.9962, val acc 0.9694, test acc 0.9687, took 6.85 sec.
# Epoch 388: T.cost 0.008071, Train acc 0.99748, val acc 0.9663, test acc 0.9686, took 6.91 sec.
# Epoch 389: T.cost 0.015438, Train acc 0.99552, val acc 0.969, test acc 0.9678, took 6.86 sec.
# Epoch 390: T.cost 0.018387, Train acc 0.9944, val acc 0.9702, test acc 0.9682, took 6.93 sec.
# Epoch 391: T.cost 0.012202, Train acc 0.9959, val acc 0.9664, test acc 0.9668, took 7.01 sec.
# Epoch 392: T.cost 0.008719, Train acc 0.99716, val acc 0.9697, test acc 0.9697, took 6.98 sec.
# Epoch 393: T.cost 0.006115, Train acc 0.99826, val acc 0.9684, test acc 0.9676, took 6.91 sec.
# Epoch 394: T.cost 0.009637, Train acc 0.99696, val acc 0.9692, test acc 0.9692, took 6.92 sec.
# Epoch 395: T.cost 0.007227, Train acc 0.99734, val acc 0.9681, test acc 0.9697, took 6.92 sec.
# Epoch 396: T.cost 0.011244, Train acc 0.99646, val acc 0.9676, test acc 0.9697, took 6.71 sec.
# Epoch 397: T.cost 0.004298, Train acc 0.99848, val acc 0.9666, test acc 0.9693, took 6.88 sec.
# Epoch 398: T.cost 0.005293, Train acc 0.9982, val acc 0.9688, test acc 0.9689, took 6.91 sec.
# New LR: 0.000817907059682
# Epoch 399: T.cost 0.005925, Train acc 0.99804, val acc 0.9688, test acc 0.9704, took 6.96 sec.
# Epoch 400: T.cost 0.005881, Train acc 0.99806, val acc 0.9682, test acc 0.9669, took 6.91 sec.
# Epoch 401: T.cost 0.006673, Train acc 0.9978, val acc 0.9714, test acc 0.9675, took 6.92 sec.
# Epoch 402: T.cost 0.007062, Train acc 0.99778, val acc 0.9694, test acc 0.9688, took 7.07 sec.
# Epoch 403: T.cost 0.009792, Train acc 0.99666, val acc 0.9692, test acc 0.9652, took 6.97 sec.
# Epoch 404: T.cost 0.008369, Train acc 0.99724, val acc 0.9702, test acc 0.9695, took 7.07 sec.
# Epoch 405: T.cost 0.005038, Train acc 0.99834, val acc 0.9704, test acc 0.9681, took 7.09 sec.
# Epoch 406: T.cost 0.006010, Train acc 0.99816, val acc 0.9659, test acc 0.9685, took 7.04 sec.
# Epoch 407: T.cost 0.005429, Train acc 0.99826, val acc 0.9676, test acc 0.9696, took 6.77 sec.
# Epoch 408: T.cost 0.010970, Train acc 0.99638, val acc 0.9685, test acc 0.9691, took 7.02 sec.
# Epoch 409: T.cost 0.015646, Train acc 0.99524, val acc 0.9655, test acc 0.9696, took 6.92 sec.
# Epoch 410: T.cost 0.007445, Train acc 0.99744, val acc 0.9681, test acc 0.9692, took 6.99 sec.
# Epoch 411: T.cost 0.008281, Train acc 0.9973, val acc 0.9679, test acc 0.9696, took 6.93 sec.
# Epoch 412: T.cost 0.005987, Train acc 0.99784, val acc 0.9673, test acc 0.9677, took 6.91 sec.
# Epoch 413: T.cost 0.005852, Train acc 0.99814, val acc 0.9683, test acc 0.9692, took 7.0 sec.
# Epoch 414: T.cost 0.004893, Train acc 0.99842, val acc 0.9698, test acc 0.9682, took 6.91 sec.
# Epoch 415: T.cost 0.003746, Train acc 0.99878, val acc 0.9668, test acc 0.9671, took 6.95 sec.
# Epoch 416: T.cost 0.004779, Train acc 0.99826, val acc 0.9706, test acc 0.9671, took 7.02 sec.
# Epoch 417: T.cost 0.006467, Train acc 0.99794, val acc 0.9691, test acc 0.9644, took 6.93 sec.
# Epoch 418: T.cost 0.011583, Train acc 0.99656, val acc 0.9639, test acc 0.9651, took 6.99 sec.
# New LR: 0.000809727972373
# Epoch 419: T.cost 0.010959, Train acc 0.99642, val acc 0.9661, test acc 0.965, took 6.86 sec.
# Epoch 420: T.cost 0.007772, Train acc 0.99716, val acc 0.9696, test acc 0.9663, took 7.01 sec.
# Epoch 421: T.cost 0.005652, Train acc 0.9983, val acc 0.971, test acc 0.9688, took 7.03 sec.
# Epoch 422: T.cost 0.004046, Train acc 0.9986, val acc 0.968, test acc 0.9655, took 6.99 sec.
# Epoch 423: T.cost 0.016095, Train acc 0.99534, val acc 0.9654, test acc 0.9646, took 6.89 sec.
# Epoch 424: T.cost 0.006755, Train acc 0.99794, val acc 0.9674, test acc 0.9678, took 6.33 sec.
# Epoch 425: T.cost 0.007749, Train acc 0.99742, val acc 0.9685, test acc 0.9701, took 6.27 sec.
# Epoch 426: T.cost 0.009386, Train acc 0.9971, val acc 0.9654, test acc 0.9655, took 6.5 sec.
# Epoch 427: T.cost 0.007584, Train acc 0.9976, val acc 0.9675, test acc 0.9697, took 6.31 sec.
# Epoch 428: T.cost 0.004285, Train acc 0.99846, val acc 0.9692, test acc 0.9707, took 6.23 sec.
# Epoch 429: T.cost 0.005511, Train acc 0.99804, val acc 0.9687, test acc 0.9695, took 6.48 sec.
# Epoch 430: T.cost 0.006525, Train acc 0.9979, val acc 0.9677, test acc 0.9694, took 6.21 sec.
# Epoch 431: T.cost 0.005701, Train acc 0.99828, val acc 0.9688, test acc 0.9686, took 6.44 sec.
# Epoch 432: T.cost 0.008527, Train acc 0.99732, val acc 0.9658, test acc 0.9681, took 6.23 sec.
# Epoch 433: T.cost 0.004813, Train acc 0.99836, val acc 0.967, test acc 0.9701, took 6.49 sec.
# Epoch 434: T.cost 0.003606, Train acc 0.99878, val acc 0.9692, test acc 0.9692, took 6.25 sec.
# Epoch 435: T.cost 0.006648, Train acc 0.99804, val acc 0.9675, test acc 0.9666, took 6.22 sec.
# Epoch 436: T.cost 0.008268, Train acc 0.9976, val acc 0.965, test acc 0.9687, took 6.46 sec.
# Epoch 437: T.cost 0.009567, Train acc 0.99682, val acc 0.9679, test acc 0.9651, took 6.23 sec.
# Epoch 438: T.cost 0.008863, Train acc 0.99744, val acc 0.9657, test acc 0.9683, took 6.5 sec.
# New LR: 0.000801630713395
# Epoch 439: T.cost 0.014196, Train acc 0.99602, val acc 0.9669, test acc 0.9689, took 6.28 sec.
# Epoch 440: T.cost 0.006074, Train acc 0.99828, val acc 0.9686, test acc 0.9699, took 6.22 sec.
# Epoch 441: T.cost 0.004651, Train acc 0.9984, val acc 0.9676, test acc 0.9703, took 6.5 sec.
# Epoch 442: T.cost 0.007623, Train acc 0.99752, val acc 0.9701, test acc 0.9696, took 6.22 sec.
# Epoch 443: T.cost 0.008962, Train acc 0.99696, val acc 0.9688, test acc 0.9676, took 6.43 sec.
# Epoch 444: T.cost 0.004952, Train acc 0.99834, val acc 0.9689, test acc 0.9659, took 6.23 sec.
# Epoch 445: T.cost 0.009188, Train acc 0.99712, val acc 0.9664, test acc 0.9659, took 6.56 sec.
# Epoch 446: T.cost 0.010144, Train acc 0.99684, val acc 0.9675, test acc 0.9672, took 6.28 sec.
# Epoch 447: T.cost 0.006815, Train acc 0.99788, val acc 0.9681, test acc 0.9669, took 6.25 sec.
# Epoch 448: T.cost 0.006413, Train acc 0.99788, val acc 0.9675, test acc 0.9682, took 6.47 sec.
# Epoch 449: T.cost 0.011993, Train acc 0.99652, val acc 0.9685, test acc 0.9687, took 6.24 sec.
# Epoch 450: T.cost 0.006102, Train acc 0.9979, val acc 0.9673, test acc 0.9693, took 6.51 sec.
# Epoch 451: T.cost 0.006398, Train acc 0.99802, val acc 0.966, test acc 0.9682, took 6.28 sec.
# Epoch 452: T.cost 0.007860, Train acc 0.99746, val acc 0.966, test acc 0.9679, took 6.26 sec.
# Epoch 453: T.cost 0.004499, Train acc 0.9987, val acc 0.9686, test acc 0.969, took 6.5 sec.
# Epoch 454: T.cost 0.014516, Train acc 0.9957, val acc 0.9656, test acc 0.9662, took 6.26 sec.
# Epoch 455: T.cost 0.007419, Train acc 0.99778, val acc 0.9667, test acc 0.9677, took 6.54 sec.
# Epoch 456: T.cost 0.006241, Train acc 0.99806, val acc 0.9672, test acc 0.9698, took 6.29 sec.
# Epoch 457: T.cost 0.007692, Train acc 0.9974, val acc 0.9683, test acc 0.9698, took 6.25 sec.
# Epoch 458: T.cost 0.008755, Train acc 0.99716, val acc 0.9686, test acc 0.9691, took 6.53 sec.
# New LR: 0.000793614418362
# Epoch 459: T.cost 0.007497, Train acc 0.9975, val acc 0.9693, test acc 0.9677, took 6.24 sec.
# Epoch 460: T.cost 0.006735, Train acc 0.99794, val acc 0.9673, test acc 0.9675, took 6.46 sec.
# Epoch 461: T.cost 0.008954, Train acc 0.9971, val acc 0.9654, test acc 0.9694, took 6.25 sec.
# Epoch 462: T.cost 0.010192, Train acc 0.99662, val acc 0.9682, test acc 0.9649, took 6.52 sec.
# Epoch 463: T.cost 0.008352, Train acc 0.99728, val acc 0.9647, test acc 0.9653, took 6.3 sec.
# Epoch 464: T.cost 0.007640, Train acc 0.99756, val acc 0.9676, test acc 0.9663, took 6.29 sec.
# Epoch 465: T.cost 0.006507, Train acc 0.99778, val acc 0.9688, test acc 0.9697, took 6.45 sec.
# Epoch 466: T.cost 0.008169, Train acc 0.99762, val acc 0.9686, test acc 0.968, took 6.26 sec.
# Epoch 467: T.cost 0.007998, Train acc 0.99722, val acc 0.9672, test acc 0.9698, took 6.52 sec.
# Epoch 468: T.cost 0.009210, Train acc 0.99714, val acc 0.9657, test acc 0.9628, took 6.3 sec.
# Epoch 469: T.cost 0.008342, Train acc 0.99728, val acc 0.9676, test acc 0.97, took 6.26 sec.
# Epoch 470: T.cost 0.009411, Train acc 0.99684, val acc 0.9648, test acc 0.9646, took 6.48 sec.
# Epoch 471: T.cost 0.008473, Train acc 0.99726, val acc 0.9689, test acc 0.9637, took 6.26 sec.
# Epoch 472: T.cost 0.013579, Train acc 0.9963, val acc 0.9649, test acc 0.9646, took 6.55 sec.
# Epoch 473: T.cost 0.014698, Train acc 0.99556, val acc 0.9651, test acc 0.9673, took 6.32 sec.
# Epoch 474: T.cost 0.008199, Train acc 0.99744, val acc 0.9688, test acc 0.9689, took 6.26 sec.
# Epoch 475: T.cost 0.004522, Train acc 0.9985, val acc 0.9661, test acc 0.9689, took 6.5 sec.
# Epoch 476: T.cost 0.004940, Train acc 0.99852, val acc 0.9692, test acc 0.9684, took 6.25 sec.
# Epoch 477: T.cost 0.005993, Train acc 0.99788, val acc 0.9685, test acc 0.968, took 6.56 sec.
# Epoch 478: T.cost 0.008567, Train acc 0.99734, val acc 0.9652, test acc 0.9647, took 6.32 sec.
# New LR: 0.000785678280517
# Epoch 479: T.cost 0.005828, Train acc 0.99814, val acc 0.9683, test acc 0.9674, took 6.26 sec.
# Epoch 480: T.cost 0.006617, Train acc 0.99798, val acc 0.9663, test acc 0.9667, took 6.61 sec.
# Epoch 481: T.cost 0.003597, Train acc 0.99876, val acc 0.97, test acc 0.9673, took 6.26 sec.
# Epoch 482: T.cost 0.004949, Train acc 0.99842, val acc 0.9688, test acc 0.9687, took 6.54 sec.
# Epoch 483: T.cost 0.004409, Train acc 0.99842, val acc 0.9695, test acc 0.9655, took 6.33 sec.
# Epoch 484: T.cost 0.006144, Train acc 0.99784, val acc 0.9689, test acc 0.9649, took 6.28 sec.
# Epoch 485: T.cost 0.014817, Train acc 0.99548, val acc 0.9652, test acc 0.9673, took 6.99 sec.
# Epoch 486: T.cost 0.006313, Train acc 0.99796, val acc 0.9677, test acc 0.9689, took 7.2 sec.
# Epoch 487: T.cost 0.007327, Train acc 0.99774, val acc 0.9658, test acc 0.9683, took 6.85 sec.
# Epoch 488: T.cost 0.011216, Train acc 0.99682, val acc 0.9657, test acc 0.9662, took 7.25 sec.
# Epoch 489: T.cost 0.019590, Train acc 0.99486, val acc 0.9686, test acc 0.9685, took 6.74 sec.
# Epoch 490: T.cost 0.009510, Train acc 0.99706, val acc 0.9662, test acc 0.9652, took 6.67 sec.
# Epoch 491: T.cost 0.005188, Train acc 0.99826, val acc 0.9672, test acc 0.9682, took 7.15 sec.
# Epoch 492: T.cost 0.003142, Train acc 0.99904, val acc 0.9668, test acc 0.9715, took 6.62 sec.
# Epoch 493: T.cost 0.003764, Train acc 0.9987, val acc 0.9689, test acc 0.9673, took 6.89 sec.
# Epoch 494: T.cost 0.007361, Train acc 0.99792, val acc 0.9676, test acc 0.9699, took 7.27 sec.
# Epoch 495: T.cost 0.004499, Train acc 0.99848, val acc 0.9692, test acc 0.9671, took 7.06 sec.
# Epoch 496: T.cost 0.009482, Train acc 0.99696, val acc 0.9666, test acc 0.9645, took 7.05 sec.
# Epoch 497: T.cost 0.010376, Train acc 0.99668, val acc 0.9681, test acc 0.9698, took 7.07 sec.
# Epoch 498: T.cost 0.007389, Train acc 0.99774, val acc 0.9669, test acc 0.9677, took 6.57 sec.
# New LR: 0.000777821493102
# Epoch 499: T.cost 0.003853, Train acc 0.9985, val acc 0.9697, test acc 0.9693, took 7.27 sec.
# Epoch 500: T.cost 0.003582, Train acc 0.99894, val acc 0.9659, test acc 0.968, took 6.69 sec.
# Epoch 501: T.cost 0.004521, Train acc 0.99846, val acc 0.9698, test acc 0.9699, took 7.19 sec.
# ...
# Epoch 1336: T.cost 0.004103, Train acc 0.99874, val acc 0.9694, test acc 0.9666, took 8.04 sec.
# Epoch 1337: T.cost 0.002584, Train acc 0.9993, val acc 0.9691, test acc 0.969, took 8.03 sec.
# Epoch 1338: T.cost 0.000584, Train acc 0.99984, val acc 0.9719, test acc 0.9691, took 8.08 sec.
# New LR: 0.000509985902463
# Epoch 1339: T.cost 0.000621, Train acc 0.99978, val acc 0.9704, test acc 0.9685, took 8.02 sec.
# Epoch 1340: T.cost 0.000459, Train acc 0.99984, val acc 0.9704, test acc 0.9699, took 8.0 sec.
# Epoch 1341: T.cost 0.000692, Train acc 0.9998, val acc 0.9699, test acc 0.9703, took 8.0 sec.
# Epoch 1342: T.cost 0.000553, Train acc 0.9998, val acc 0.9696, test acc 0.9711, took 8.13 sec.
# Epoch 1343: T.cost 0.004828, Train acc 0.99892, val acc 0.9685, test acc 0.967, took 8.04 sec.
# Epoch 1344: T.cost 0.007139, Train acc 0.99776, val acc 0.9665, test acc 0.9687, took 8.0 sec.
# Epoch 1345: T.cost 0.005775, Train acc 0.99822, val acc 0.9699, test acc 0.9693, took 8.08 sec.
# Epoch 1346: T.cost 0.003785, Train acc 0.99898, val acc 0.9692, test acc 0.9696, took 8.04 sec.
# Epoch 1347: T.cost 0.001846, Train acc 0.99944, val acc 0.9693, test acc 0.9679, took 8.04 sec.
# Epoch 1348: T.cost 0.001025, Train acc 0.99972, val acc 0.9709, test acc 0.9671, took 8.05 sec.
# Epoch 1349: T.cost 0.000656, Train acc 0.99982, val acc 0.969, test acc 0.9694, took 8.01 sec.
# Epoch 1350: T.cost 0.000936, Train acc 0.99968, val acc 0.9691, test acc 0.9688, took 8.06 sec.
# Epoch 1351: T.cost 0.001423, Train acc 0.99946, val acc 0.9689, test acc 0.9672, took 8.06 sec.
# Epoch 1352: T.cost 0.001406, Train acc 0.99958, val acc 0.9708, test acc 0.9652, took 7.99 sec.
# Epoch 1353: T.cost 0.005202, Train acc 0.99874, val acc 0.9686, test acc 0.9656, took 8.07 sec.
# Epoch 1354: T.cost 0.006579, Train acc 0.9983, val acc 0.9689, test acc 0.9701, took 8.11 sec.
# Epoch 1355: T.cost 0.001623, Train acc 0.99952, val acc 0.9684, test acc 0.9657, took 7.86 sec.
# Epoch 1356: T.cost 0.003469, Train acc 0.99894, val acc 0.969, test acc 0.969, took 7.94 sec.
# Epoch 1357: T.cost 0.002260, Train acc 0.99934, val acc 0.9704, test acc 0.9665, took 7.87 sec.
# Epoch 1358: T.cost 0.001075, Train acc 0.99962, val acc 0.9712, test acc 0.9671, took 8.35 sec.
# New LR: 0.000504886038252
# Epoch 1359: T.cost 0.001165, Train acc 0.99964, val acc 0.9676, test acc 0.965, took 7.94 sec.
# Epoch 1360: T.cost 0.000717, Train acc 0.9997, val acc 0.97, test acc 0.9687, took 8.24 sec.
# Epoch 1361: T.cost 0.000544, Train acc 0.99984, val acc 0.9699, test acc 0.9679, took 7.96 sec.
# Epoch 1362: T.cost 0.000973, Train acc 0.99972, val acc 0.9682, test acc 0.9683, took 7.92 sec.
# Epoch 1363: T.cost 0.002000, Train acc 0.99926, val acc 0.9691, test acc 0.9701, took 7.98 sec.
# Epoch 1364: T.cost 0.003557, Train acc 0.99892, val acc 0.9688, test acc 0.9686, took 7.89 sec.
# Epoch 1365: T.cost 0.004755, Train acc 0.99888, val acc 0.9666, test acc 0.9654, took 7.99 sec.
# Epoch 1366: T.cost 0.003090, Train acc 0.99906, val acc 0.9676, test acc 0.9687, took 7.83 sec.
# Epoch 1367: T.cost 0.002938, Train acc 0.99934, val acc 0.9672, test acc 0.9663, took 7.86 sec.
# Epoch 1368: T.cost 0.006051, Train acc 0.99848, val acc 0.9667, test acc 0.9665, took 8.2 sec.
# Epoch 1369: T.cost 0.007721, Train acc 0.99794, val acc 0.9705, test acc 0.9664, took 8.07 sec.
# Epoch 1370: T.cost 0.001412, Train acc 0.99956, val acc 0.9697, test acc 0.9672, took 8.18 sec.
# Epoch 1371: T.cost 0.000772, Train acc 0.9998, val acc 0.9717, test acc 0.9674, took 8.05 sec.
# Epoch 1372: T.cost 0.000958, Train acc 0.99972, val acc 0.9692, test acc 0.9665, took 7.91 sec.
# Epoch 1373: T.cost 0.001759, Train acc 0.99938, val acc 0.9718, test acc 0.9653, took 7.86 sec.
# Epoch 1374: T.cost 0.000614, Train acc 0.99986, val acc 0.9731, test acc 0.9687, took 8.0 sec.
# Epoch 1375: T.cost 0.000551, Train acc 0.99978, val acc 0.972, test acc 0.9664, took 8.39 sec.
# Epoch 1376: T.cost 0.000314, Train acc 0.9999, val acc 0.9697, test acc 0.9696, took 7.9 sec.
# Epoch 1377: T.cost 0.000803, Train acc 0.9998, val acc 0.9715, test acc 0.9674, took 8.02 sec.
# Epoch 1378: T.cost 0.002321, Train acc 0.99926, val acc 0.9691, test acc 0.9683, took 7.96 sec.
# New LR: 0.000499837172683
# Epoch 1379: T.cost 0.004146, Train acc 0.99888, val acc 0.9695, test acc 0.9671, took 7.89 sec.
# Epoch 1380: T.cost 0.002163, Train acc 0.99932, val acc 0.9695, test acc 0.9677, took 7.99 sec.
# Epoch 1381: T.cost 0.003454, Train acc 0.99896, val acc 0.9672, test acc 0.9659, took 8.33 sec.
# Epoch 1382: T.cost 0.003426, Train acc 0.99888, val acc 0.9691, test acc 0.9678, took 8.11 sec.
# Epoch 1383: T.cost 0.001243, Train acc 0.99962, val acc 0.9707, test acc 0.9668, took 8.06 sec.
# Epoch 1384: T.cost 0.001456, Train acc 0.99954, val acc 0.9692, test acc 0.9676, took 8.11 sec.
# Epoch 1385: T.cost 0.000585, Train acc 0.99986, val acc 0.9704, test acc 0.9699, took 8.05 sec.
# Epoch 1386: T.cost 0.001816, Train acc 0.99942, val acc 0.9715, test acc 0.967, took 8.0 sec.
# Epoch 1387: T.cost 0.002393, Train acc 0.9993, val acc 0.9707, test acc 0.9677, took 8.12 sec.
# Epoch 1388: T.cost 0.001456, Train acc 0.99954, val acc 0.9683, test acc 0.9661, took 8.0 sec.
# Epoch 1389: T.cost 0.000891, Train acc 0.99964, val acc 0.9712, test acc 0.9693, took 8.09 sec.
# Epoch 1390: T.cost 0.003438, Train acc 0.99924, val acc 0.9666, test acc 0.9647, took 7.93 sec.
# Epoch 1391: T.cost 0.003964, Train acc 0.99882, val acc 0.9702, test acc 0.9675, took 7.85 sec.
# Epoch 1392: T.cost 0.002211, Train acc 0.99934, val acc 0.9713, test acc 0.9693, took 8.17 sec.
# Epoch 1393: T.cost 0.002232, Train acc 0.99932, val acc 0.9705, test acc 0.9676, took 7.9 sec.
# Epoch 1394: T.cost 0.002456, Train acc 0.99922, val acc 0.9717, test acc 0.9679, took 7.89 sec.
# Epoch 1395: T.cost 0.005081, Train acc 0.99876, val acc 0.9662, test acc 0.9667, took 8.02 sec.
# Epoch 1396: T.cost 0.004343, Train acc 0.99876, val acc 0.9705, test acc 0.967, took 7.95 sec.
# Epoch 1397: T.cost 0.001359, Train acc 0.9996, val acc 0.9716, test acc 0.9676, took 7.96 sec.
# Epoch 1398: T.cost 0.001029, Train acc 0.99968, val acc 0.9691, test acc 0.9669, took 7.92 sec.
# New LR: 0.000494838787126
# Epoch 1399: T.cost 0.002208, Train acc 0.99928, val acc 0.9651, test acc 0.968, took 7.91 sec.
# Epoch 1400: T.cost 0.007457, Train acc 0.99828, val acc 0.9688, test acc 0.9673, took 7.27 sec.
# Epoch 1401: T.cost 0.003431, Train acc 0.99914, val acc 0.9708, test acc 0.9655, took 7.59 sec.
# Epoch 1402: T.cost 0.001570, Train acc 0.99954, val acc 0.9689, test acc 0.9678, took 7.43 sec.
# Epoch 1403: T.cost 0.002680, Train acc 0.99934, val acc 0.9717, test acc 0.9696, took 7.24 sec.
# Epoch 1404: T.cost 0.000931, Train acc 0.9997, val acc 0.9695, test acc 0.9708, took 7.24 sec.
# Epoch 1405: T.cost 0.000435, Train acc 0.99986, val acc 0.9716, test acc 0.9695, took 7.25 sec.
# Epoch 1406: T.cost 0.001105, Train acc 0.99974, val acc 0.969, test acc 0.9674, took 7.24 sec.
# Epoch 1407: T.cost 0.002805, Train acc 0.99922, val acc 0.9671, test acc 0.9646, took 7.6 sec.
# Epoch 1408: T.cost 0.002802, Train acc 0.9992, val acc 0.971, test acc 0.9691, took 7.21 sec.
# Epoch 1409: T.cost 0.001563, Train acc 0.99946, val acc 0.9712, test acc 0.9671, took 7.2 sec.
# Epoch 1410: T.cost 0.002130, Train acc 0.99948, val acc 0.9703, test acc 0.9681, took 7.21 sec.
# Epoch 1411: T.cost 0.002675, Train acc 0.99922, val acc 0.9704, test acc 0.9698, took 7.27 sec.
# Epoch 1412: T.cost 0.001752, Train acc 0.99936, val acc 0.9696, test acc 0.9681, took 7.22 sec.
# Epoch 1413: T.cost 0.000380, Train acc 0.99982, val acc 0.9669, test acc 0.9683, took 7.59 sec.
# Epoch 1414: T.cost 0.000775, Train acc 0.99978, val acc 0.9685, test acc 0.9663, took 7.25 sec.
# Epoch 1415: T.cost 0.001958, Train acc 0.99944, val acc 0.9687, test acc 0.9682, took 7.19 sec.
# Epoch 1416: T.cost 0.000797, Train acc 0.99976, val acc 0.9687, test acc 0.9694, took 7.26 sec.
# Epoch 1417: T.cost 0.000613, Train acc 0.99988, val acc 0.9705, test acc 0.9684, took 7.27 sec.
# Epoch 1418: T.cost 0.000420, Train acc 0.99986, val acc 0.9681, test acc 0.9689, took 7.26 sec.
# New LR: 0.000489890420577
# Epoch 1419: T.cost 0.001718, Train acc 0.9995, val acc 0.9643, test acc 0.9683, took 7.77 sec.
# Epoch 1420: T.cost 0.003773, Train acc 0.99874, val acc 0.9651, test acc 0.9661, took 7.31 sec.
# Epoch 1421: T.cost 0.003669, Train acc 0.999, val acc 0.9674, test acc 0.9674, took 7.28 sec.
# Epoch 1422: T.cost 0.004013, Train acc 0.99882, val acc 0.9659, test acc 0.9676, took 7.26 sec.
# Epoch 1423: T.cost 0.003145, Train acc 0.99912, val acc 0.9694, test acc 0.9704, took 7.28 sec.
# Epoch 1424: T.cost 0.001183, Train acc 0.99962, val acc 0.9697, test acc 0.9683, took 7.31 sec.
# Epoch 1425: T.cost 0.001200, Train acc 0.99948, val acc 0.9687, test acc 0.968, took 7.66 sec.
# Epoch 1426: T.cost 0.002212, Train acc 0.9993, val acc 0.9678, test acc 0.9699, took 7.34 sec.
# Epoch 1427: T.cost 0.004862, Train acc 0.9988, val acc 0.968, test acc 0.9679, took 7.26 sec.
# Epoch 1428: T.cost 0.003286, Train acc 0.99906, val acc 0.9697, test acc 0.9695, took 7.37 sec.
# Epoch 1429: T.cost 0.003141, Train acc 0.99918, val acc 0.9693, test acc 0.968, took 7.58 sec.
# Epoch 1430: T.cost 0.001112, Train acc 0.99956, val acc 0.9691, test acc 0.9702, took 7.54 sec.
# Epoch 1431: T.cost 0.000722, Train acc 0.99978, val acc 0.9703, test acc 0.9721, took 7.58 sec.
# Epoch 1432: T.cost 0.000875, Train acc 0.99964, val acc 0.9687, test acc 0.9683, took 7.61 sec.
# Epoch 1433: T.cost 0.001569, Train acc 0.99954, val acc 0.9709, test acc 0.9672, took 7.84 sec.
# Epoch 1434: T.cost 0.004834, Train acc 0.99878, val acc 0.9691, test acc 0.9693, took 7.74 sec.
# Epoch 1435: T.cost 0.001200, Train acc 0.99956, val acc 0.9683, test acc 0.9696, took 7.58 sec.
# Epoch 1436: T.cost 0.000237, Train acc 0.99996, val acc 0.9708, test acc 0.9676, took 7.49 sec.
# Epoch 1437: T.cost 0.000093, Train acc 1.0, val acc 0.9714, test acc 0.9694, took 7.57 sec.
# Epoch 1438: T.cost 0.000155, Train acc 0.99994, val acc 0.9689, test acc 0.9708, took 7.6 sec.
# New LR: 0.000484991496778
# Epoch 1439: T.cost 0.000194, Train acc 0.99996, val acc 0.9695, test acc 0.9684, took 7.54 sec.
# Epoch 1440: T.cost 0.000290, Train acc 0.99994, val acc 0.9709, test acc 0.9694, took 7.59 sec.
# Epoch 1441: T.cost 0.001458, Train acc 0.9996, val acc 0.9684, test acc 0.9671, took 7.58 sec.
# Epoch 1442: T.cost 0.007551, Train acc 0.9981, val acc 0.963, test acc 0.9651, took 7.63 sec.
# Epoch 1443: T.cost 0.007110, Train acc 0.9981, val acc 0.9705, test acc 0.9642, took 7.91 sec.
# Epoch 1444: T.cost 0.003698, Train acc 0.9988, val acc 0.9673, test acc 0.9671, took 7.85 sec.
# Epoch 1445: T.cost 0.001868, Train acc 0.9995, val acc 0.9676, test acc 0.9678, took 7.61 sec.
# Epoch 1446: T.cost 0.001261, Train acc 0.99966, val acc 0.969, test acc 0.9684, took 7.58 sec.
# Epoch 1447: T.cost 0.001054, Train acc 0.9997, val acc 0.969, test acc 0.9716, took 7.62 sec.
# Epoch 1448: T.cost 0.000908, Train acc 0.99976, val acc 0.971, test acc 0.9717, took 7.59 sec.
# Epoch 1449: T.cost 0.001057, Train acc 0.99952, val acc 0.9673, test acc 0.9689, took 7.62 sec.
# Epoch 1450: T.cost 0.000940, Train acc 0.99974, val acc 0.972, test acc 0.97, took 7.68 sec.
# Epoch 1451: T.cost 0.002136, Train acc 0.99924, val acc 0.9683, test acc 0.9697, took 7.66 sec.
# Epoch 1452: T.cost 0.001583, Train acc 0.9995, val acc 0.9706, test acc 0.9691, took 7.69 sec.
# Epoch 1453: T.cost 0.002749, Train acc 0.9991, val acc 0.9705, test acc 0.9675, took 7.66 sec.
# Epoch 1454: T.cost 0.001972, Train acc 0.99936, val acc 0.9703, test acc 0.9702, took 7.62 sec.
# Epoch 1455: T.cost 0.001937, Train acc 0.99936, val acc 0.9707, test acc 0.9686, took 7.93 sec.
# Epoch 1456: T.cost 0.001426, Train acc 0.99952, val acc 0.9696, test acc 0.9677, took 7.83 sec.
# Epoch 1457: T.cost 0.000789, Train acc 0.99976, val acc 0.9701, test acc 0.9695, took 7.82 sec.
# Epoch 1458: T.cost 0.000752, Train acc 0.99972, val acc 0.9682, test acc 0.9695, took 7.67 sec.
# New LR: 0.000480141583539
# Epoch 1459: T.cost 0.002288, Train acc 0.99942, val acc 0.9694, test acc 0.9699, took 7.55 sec.
# Epoch 1460: T.cost 0.001738, Train acc 0.99934, val acc 0.968, test acc 0.968, took 7.65 sec.
# Epoch 1461: T.cost 0.009126, Train acc 0.99776, val acc 0.9687, test acc 0.968, took 7.68 sec.
# Epoch 1462: T.cost 0.002290, Train acc 0.99924, val acc 0.9684, test acc 0.9698, took 7.65 sec.
# Epoch 1463: T.cost 0.002499, Train acc 0.99936, val acc 0.9688, test acc 0.967, took 7.66 sec.
# Epoch 1464: T.cost 0.001727, Train acc 0.99952, val acc 0.969, test acc 0.9666, took 7.76 sec.
# Epoch 1465: T.cost 0.000665, Train acc 0.9998, val acc 0.9685, test acc 0.9697, took 7.72 sec.
# Epoch 1466: T.cost 0.000487, Train acc 0.99986, val acc 0.9695, test acc 0.9687, took 7.75 sec.
# Epoch 1467: T.cost 0.000808, Train acc 0.99976, val acc 0.9698, test acc 0.9709, took 7.75 sec.
# Epoch 1468: T.cost 0.001639, Train acc 0.99962, val acc 0.9666, test acc 0.9683, took 7.78 sec.
# Epoch 1469: T.cost 0.005452, Train acc 0.99868, val acc 0.9663, test acc 0.967, took 7.98 sec.
# Epoch 1470: T.cost 0.002385, Train acc 0.99928, val acc 0.9678, test acc 0.969, took 7.92 sec.
# Epoch 1471: T.cost 0.001835, Train acc 0.99948, val acc 0.965, test acc 0.966, took 7.92 sec.
# Epoch 1472: T.cost 0.001269, Train acc 0.9996, val acc 0.9679, test acc 0.9663, took 7.95 sec.
# Epoch 1473: T.cost 0.001047, Train acc 0.99972, val acc 0.9693, test acc 0.9685, took 7.97 sec.
# Epoch 1474: T.cost 0.001318, Train acc 0.9997, val acc 0.9671, test acc 0.9692, took 7.74 sec.
# Epoch 1475: T.cost 0.001052, Train acc 0.99964, val acc 0.9697, test acc 0.9697, took 7.7 sec.
# Epoch 1476: T.cost 0.001306, Train acc 0.99954, val acc 0.9704, test acc 0.9689, took 7.73 sec.
# Epoch 1477: T.cost 0.000946, Train acc 0.99972, val acc 0.9687, test acc 0.9689, took 7.77 sec.
# Epoch 1478: T.cost 0.001626, Train acc 0.9995, val acc 0.968, test acc 0.9672, took 7.68 sec.
# New LR: 0.000475340162229
# Epoch 1479: T.cost 0.001475, Train acc 0.99964, val acc 0.9701, test acc 0.9699, took 7.82 sec.
# Epoch 1480: T.cost 0.001990, Train acc 0.9995, val acc 0.9677, test acc 0.9675, took 7.8 sec.
# Epoch 1481: T.cost 0.003211, Train acc 0.99918, val acc 0.9666, test acc 0.9659, took 7.77 sec.
# Epoch 1482: T.cost 0.002547, Train acc 0.99918, val acc 0.9683, test acc 0.9689, took 7.88 sec.
# Epoch 1483: T.cost 0.004273, Train acc 0.99882, val acc 0.9649, test acc 0.9671, took 7.87 sec.
# Epoch 1484: T.cost 0.003411, Train acc 0.99908, val acc 0.9683, test acc 0.9689, took 7.97 sec.
# Epoch 1485: T.cost 0.000707, Train acc 0.99974, val acc 0.9693, test acc 0.9699, took 7.92 sec.
# Epoch 1486: T.cost 0.002343, Train acc 0.99924, val acc 0.9693, test acc 0.9686, took 7.93 sec.
# Epoch 1487: T.cost 0.001968, Train acc 0.9994, val acc 0.9683, test acc 0.9661, took 7.88 sec.
# Epoch 1488: T.cost 0.000513, Train acc 0.99984, val acc 0.9697, test acc 0.9679, took 7.86 sec.
# Epoch 1489: T.cost 0.000536, Train acc 0.99988, val acc 0.9691, test acc 0.9676, took 7.89 sec.
# Epoch 1490: T.cost 0.000384, Train acc 0.99992, val acc 0.9703, test acc 0.9683, took 7.96 sec.
# Epoch 1491: T.cost 0.000237, Train acc 0.99994, val acc 0.971, test acc 0.9688, took 7.9 sec.
# Epoch 1492: T.cost 0.000701, Train acc 0.99978, val acc 0.9687, test acc 0.9658, took 8.04 sec.
# Epoch 1493: T.cost 0.001631, Train acc 0.99942, val acc 0.9699, test acc 0.9659, took 7.86 sec.
# Epoch 1494: T.cost 0.001160, Train acc 0.99964, val acc 0.9684, test acc 0.9693, took 7.97 sec.
# Epoch 1495: T.cost 0.001756, Train acc 0.99942, val acc 0.967, test acc 0.9687, took 7.99 sec.
# Epoch 1496: T.cost 0.001349, Train acc 0.99966, val acc 0.9685, test acc 0.9677, took 7.89 sec.
# Epoch 1497: T.cost 0.002860, Train acc 0.99922, val acc 0.9702, test acc 0.9678, took 7.92 sec.
# Epoch 1498: T.cost 0.000827, Train acc 0.99964, val acc 0.9691, test acc 0.9679, took 7.89 sec.
# New LR: 0.000470586771844
# Epoch 1499: T.cost 0.006629, Train acc 0.99822, val acc 0.9674, test acc 0.9688, took 7.88 sec.
#
# Total time spent: 1.0531e+04 seconds
# Traing Acc: 0.99822
# Test Acc: 0.9688
# Validation Acc: 0.9674

# %% [markdown]
# # Plot Results

# %%
plt.figure(figsize=(5,5))
plt.plot(1-np.array(train_accs), label='Training Error')
plt.plot(1-np.array(valid_accs), label='Validation Error')
plt.legend(fontsize=20)
plt.xlabel('Epoch', fontsize=8)
plt.ylabel('Error', fontsize=8)
plt.show()

# %% [markdown]
# # Histograms

# %%
# Histograms
dense_params = param_outputs.reshape((-1, 6))
disc_params = disc_outputs.reshape((-1, 6))

bin_count = 100
plot_over = True

for i in range(0, 6):
    dns = dense_params[:, i]
    
    min_dns = np.min(dense_params[:, i])
    max_dns = np.max(dense_params[:, i])
    bins_dns = np.arange(min_dns, max_dns, QUANT[i])
    
    dsc = disc_params[:, i]
    print len(np.unique(dsc))
    #PS: Using normed histograms to plot them over
    # Theta x Dense
    plt.figure()
    n, bins, patches = plt.hist(dns, bin_count, normed=plot_over, histtype='stepfilled')
    plt.setp(patches, 'facecolor', 'r', 'alpha', 0.55)
    if not plot_over:
        plt.xlabel(('Theta({0}) - Discrete Output').format(i+1))
        plt.ylabel('Frequency (Consider bin size)')
        plt.grid(True)
        plt.figure()
    
    # Theta x Discrete
    n, bins, patches = plt.hist(dsc, bins_dns, normed=plot_over, histtype='stepfilled')
    plt.setp(patches, 'facecolor', 'g', 'alpha', 0.55)
    if not plot_over:
        plt.xlabel(('Theta({0}) - Discrete Output').format(i+1))
    else:
        plt.xlabel(('Theta({0})').format(i+1))
    plt.ylabel('Frequency')
    plt.grid(True)
# Out:
# 130
# 188
# 112
# 109
# 188
# 99

# %%
plt.figure(figsize=(7,14))
for i in range(3):
    plt.subplot(321+i*2)
    plt.imshow(data['X_test'][i].reshape(DIM, DIM), cmap='gray', interpolation='none')
    if i == 0:
        plt.title('Original 60x60', fontsize=20)
    plt.axis('off')
    plt.subplot(322+i*2)
    plt.imshow(test_transform[i].reshape(DIM//3, DIM//3), cmap='gray', interpolation='none')
    if i == 0:
        plt.title('Transformed 20x20', fontsize=20)
    plt.axis('off')
plt.tight_layout()
